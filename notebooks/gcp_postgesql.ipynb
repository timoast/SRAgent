# %% [markdown]
# # Goals
#
# * Test connecting and updating a GCP Cloud SQL database

# %%
import os
import warnings
from importlib import resources
import psycopg2
from dynaconf import Dynaconf
from psycopg2.extensions import connection
import pandas as pd
from pypika import Query, Table, Field, Column, Table

# %%
from dotenv import load_dotenv
load_dotenv()
os.environ["DYNACONF"] = "test"
warnings.filterwarnings("ignore", message="pandas only supports SQLAlchemy connectable")

# %% [markdown]
# # Connect

# %%
def db_connect() -> connection:
    """Connect to the sql database"""
    s_path = None
    with resources.path("SRAgent", "settings.yml") as settings_path:
        s_path = str(settings_path)
    settings = Dynaconf(
        settings_files=["settings.yml", s_path], 
        environments=True, 
        env_switcher="DYNACONF"
    )
    # connect to db
    db_params = {
        'host': settings.db_host,
        'database': settings.db_name,
        'user': settings.db_user,
        'password': os.environ["GCP_SQL_DB_PASSWORD"],
        'port': settings.db_port,
        'connect_timeout': settings.db_timeout
    }
    return psycopg2.connect(**db_params)

conn = db_connect()
# Out:
# /tmp/ipykernel_1147974/3912594006.py:4: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path("SRAgent", "settings.yml") as settings_path:

# %%
def execute_query(stmt, conn):
    try:
        with conn.cursor() as cur:
            cur.execute(str(stmt))
            conn.commit() 
    except psycopg2.errors.DuplicateTable as e:
        print(f"Table already exists: {e}")

# %%
# list tables in pypika
def list_tables_pypika():
    tables = Table('tables', schema='information_schema')
    query = Query.from_(tables).select('table_name').where(tables.table_schema == 'public')
    with conn.cursor() as cur:
        cur.execute(str(query))
        tables = cur.fetchall()
        return tables
list_tables_pypika()
# Out:
# [('srx_srr',), ('screcounter',), ('srx_metadata',), ('eval',)]

# %% [markdown]
# # Create tables

# %%
# SRX_metadata
stmt = Query \
    .create_table("srx_metadata") \
    .columns(
        Column("id", "SERIAL", nullable=False),
        Column("database", "VARCHAR(20)", nullable=False),
        Column("entrez_id", "INT", nullable=False),
        Column("srx_accession", "VARCHAR(20)"),
        Column("is_illumina", "VARCHAR(10)"),
        Column("is_single_cell", "VARCHAR(10)"),
        Column("is_paired_end", "VARCHAR(10)"),
        Column("lib_prep", "VARCHAR(30)"),
        Column("tech_10x", "VARCHAR(30)"),
        Column("cell_prep", "VARCHAR(30)"),
        Column("organism", "VARCHAR(80)"),
        Column("tissue", "VARCHAR(80)"),
        Column("disease", "VARCHAR(100)"),
        Column("purturbation", "VARCHAR(100)"),
        Column("cell_line", "VARCHAR(100)"),
        Column("notes", "TEXT"),
    ) \
    .unique("database", "entrez_id") \
    .primary_key("id")

execute_query(stmt, conn)

# %%
# SRX_SRR
stmt = Query \
    .create_table("srx_srr") \
    .columns(
        Column("id", "SERIAL", nullable=False),
        Column("srx_accession", "VARCHAR(20)", nullable=False),
        Column("srr_accession", "VARCHAR(20)", nullable=False)
    ) \
    .unique("srx_accession", "srr_accession") \
    .primary_key("id")

execute_query(stmt, conn)
# Out:
# ---------------------------------------------------------------------------
# InFailedSqlTransaction                    Traceback (most recent call last)
# Cell In[14], line 12
#       1 # SRX_SRR
#       2 stmt = Query \
#       3     .create_table("srx_srr") \
#       4     .columns(
#    (...)
#       9     .unique("srx_accession", "srr_accession") \
#      10     .primary_key("id")
# ---> 12 execute_query(stmt, conn)
#
# Cell In[11], line 4, in execute_query(stmt, conn)
#       2 try:
#       3     with conn.cursor() as cur:
# ----> 4         cur.execute(str(stmt))
#       5         conn.commit()
#       6 except psycopg2.errors.DuplicateTable as e:
#
# InFailedSqlTransaction: current transaction is aborted, commands ignored until end of transaction block

# %%
# scRecounter log
stmt = Query \
    .create_table("screcounter") \
    .columns(
        Column("id", "SERIAL", nullable=False),
        Column("database", "VARCHAR(20)", nullable=False),
        Column("entrez_id", "INT", nullable=False),
        Column("sample", "VARCHAR(20)", nullable=False),
        Column("accession", "VARCHAR(20)", nullable=False),
        Column("pipeline_version", "VARCHAR(10)", nullable=False),
        Column("run_id", "VARCHAR(30)", nullable=False),
        Column("task_name", "VARCHAR(20)", nullable=False),
        Column("task_exit_status", "VARCHAR(10)"),
        Column("log", "TEXT", nullable=False)
    ) \
    .primary_key("id")

execute_query(stmt, conn)

# %%
# ground truth
stmt = Query \
    .create_table("eval") \
    .columns(
        Column("id", "SERIAL", nullable=False),
        Column("dataset_id", "VARCHAR(30)", nullable=False),
        Column("database", "VARCHAR(20)", nullable=False),
        Column("entrez_id", "INT", nullable=False),
        Column("srx_accession", "VARCHAR(20)"),
        Column("is_illumina", "VARCHAR(10)"),
        Column("is_single_cell", "VARCHAR(10)"),
        Column("is_paired_end", "VARCHAR(10)"),
        Column("lib_prep", "VARCHAR(30)"),
        Column("tech_10x", "VARCHAR(30)"),
        Column("organism", "VARCHAR(80)"),
        Column("cell_prep", "VARCHAR(30)"),
    ) \
    .unique("dataset_id", "database", "entrez_id") \
    .primary_key("id")

execute_query(stmt, conn)

# %% [markdown]
# # Delete tables
#
# > WARNING

# %%
# for table in ["srx_metadata", "srx_srr", "screcounter"]:
for table in ["srx_metadata"]:
#for table in ["ground_truth"]:
    stmt = Query.drop_table(table)
    print(str(stmt))
    execute_query(stmt, conn)
# Out:
# DROP TABLE "srx_metadata"

# %% [markdown]
# # Insert data

# %%
srx_metadata = Table("srx_metadata")

q = Query.into(srx_metadata) \
    .columns('database', 'entrez_id', 'srx_accession', 'is_illumina', 'is_single_cell', 'is_paired_end', 'is_10x', 'tech_10x', 'organism') \
    .insert('sra', 35087715, 'SRX25994842', 'yes', 'yes', 'yes', 'yes', '3_prime_gex', 'human')

execute_query(q, conn)

# %% [markdown]
# # Query data

# %%
tbl = Table("srx_metadata")
#tbl = Table("srx_srr")
stmt = Query \
    .from_(tbl) \
    .select("*") 
df = pd.read_sql(str(stmt), conn)
df.head()
# Out:
#   database  entrez_id srx_accession is_illumina is_single_cell is_paired_end  \
# 0      sra   33249542   SRX24914804         yes            yes           yes
# 1      sra   34603139   SRX25602353         yes            yes           yes
# 2      sra   29110064   ERX11148781         NaN            NaN           NaN
# 3      sra   25200088   SRX18216984         yes             no            no
# 4      sra   27674164   SRX20253718         yes            yes           yes
#
#          lib_prep        tech_10x       cell_prep    organism  \
# 0      Smart-seq2  not_applicable     single_cell       human
# 1    10x_Genomics           other     single_cell       human
# 2             NaN             NaN             NaN         NaN
# 3  not_applicable  not_applicable  not_applicable  metagenome
# 4    10x_Genomics     3_prime_gex     single_cell       mouse
#
#              tissue                                       disease  \
# 0             blood  Hepatitis C Virus (HCV) reinfection outcomes
# 1             PBMCs                                        unsure
# 2               NaN                                           NaN
# 3             blood                                          none
# 4  stellate ganglia                                        unsure
#
#                                         purturbation       cell_line  \
# 0  Akebia Saponin D (ASD) and TNF-induced optic n...  Memory B cells
# 1           effects of salt intake in healthy humans          unsure
# 2                                                NaN             NaN
# 3                                               none            none
# 4                                             unsure          unsure
#
#                           notes                 created_at  \
# 0  Metadata obtained by SRAgent 2024-12-18 18:23:36.181001
# 1  Metadata obtained by SRAgent 2024-12-18 18:23:36.181001
# 2  Processed by Chris Carpenter 2024-12-18 17:31:16.385013
# 3                           NaN 2024-12-18 17:31:16.385013
# 4                           NaN 2024-12-18 17:31:16.385013
#
#                   updated_at
# 0 2024-12-18 18:25:14.322667
# 1 2024-12-18 18:25:33.937056
# 2 2024-12-18 17:31:35.121583
# 3 2024-12-18 17:31:35.121583
# 4 2024-12-18 17:31:35.121583

# %%
# records with notes
tbl = Table("srx_metadata")
stmt = Query \
    .from_(tbl) \
    .where(tbl.notes != "") \
    .where(tbl.notes != "NaN") \
    .where(tbl.notes != "Processed by Chris Carpenter") \
    .select("*")  
df = pd.read_sql(str(stmt), conn)
df.tail()
# Out:
#    database  entrez_id srx_accession is_illumina is_single_cell is_paired_end  \
# 50      sra   34603118   SRX25602332         yes            yes           yes
# 51      sra   30775044   SRX22738752         yes            yes           yes
# 52      sra   30776936   SRX22740644         yes            yes           yes
# 53      sra   27454963   ERR11260966         yes            yes           yes
# 54      sra   30865410   SRX22823465         yes            yes           yes
#
#         lib_prep        tech_10x    cell_prep organism  \
# 50         other  not_applicable  single_cell    human
# 51         other  not_applicable  single_cell    mouse
# 52  10x_Genomics     5_prime_gex  single_cell    human
# 53         other  not_applicable  single_cell    mouse
# 54         other  not_applicable       unsure    mouse
#
#                         tissue  \
# 50                       PBMCs
# 51                       tumor
# 52                      spleen
# 53  ILC progenitors from femur
# 54                       tumor
#
#                                               disease  \
# 50                                               none
# 51                                             unsure
# 52                                   multiple myeloma
# 53                                             unsure
# 54  blastic plasmacytoid dendritic cell neoplasm (...
#
#                                          purturbation  \
# 50                                  salt intake study
# 51                                         PD1_Clec9a
# 52  post-infusion treatment of CB-012 Lot 1 and pN...
# 53                                             unsure
# 54                                             unsure
#
#                      cell_line                         notes  \
# 50                        none  Metadata obtained by SRAgent
# 51                       TCRB+  Metadata obtained by SRAgent
# 52  CB-011, B2M KO CAR-T cells  Metadata obtained by SRAgent
# 53                      unsure  Metadata obtained by SRAgent
# 54            endogenous CD45+  Metadata obtained by SRAgent
#
#                    created_at                 updated_at
# 50 2024-12-18 19:25:34.634022 2024-12-18 19:27:28.219439
# 51 2024-12-18 19:25:34.634022 2024-12-18 19:27:29.554980
# 52 2024-12-18 19:25:34.634022 2024-12-18 19:27:30.962313
# 53 2024-12-18 19:25:34.634022 2024-12-18 19:27:38.106818
# 54 2024-12-18 19:25:34.634022 2024-12-18 19:27:44.905183

# %%
# write to db directory
outfile = "../db/2024-12-16_srx_metadata.csv"
df.to_csv(outfile, index=False)

# %%
srx_metadata = Table("srx_metadata")
stmt = Query \
    .from_(srx_metadata) \
    .where(srx_metadata.entrez_id == 35537624) \
    .select("*") 
pd.read_sql(str(stmt), conn)
# Out:
#    id database  entrez_id srx_accession is_illumina is_single_cell  \
# 0  27      sra   35537624   SRX26314714          no            yes
#
#   is_paired_end lib_prep        tech_10x    cell_prep organism  \
# 0            no    other  not_applicable  single_cell    human
#
#                                        tissue  \
# 0  pancreatic ductal adenocarcinoma cell line
#
#                             disease  \
# 0  pancreatic ductal adenocarcinoma
#
#                                     purturbation cell_line
# 0  neoadjuvant therapy, tumor regression grade 2   HG008-T

# %%
srx_srr = Table("srx_srr")
stmt = Query \
    .from_(srx_srr) \
    .select("*") 
pd.read_sql(str(stmt), conn)
# Out:
#    id srx_accession srr_accession
# 0   1   SRX26727599   SRR31350667
# 1   2   SRX23538581   SRR27876733
# 2   3   SRX23261451   SRR27592690
# 3   4   SRX23261451   SRR27592688
# 4   5   SRX23261451   SRR27592689
# 5   6   SRX23261451   SRR27592687
# 6   8   SRX25994842   SRR30571763
# 7   9   ERX11887200   ERR12511670
# 8  10   ERX11887200   ERR12511661

# %%
tbl = Table("screcounter")
stmt = Query \
    .from_(tbl) \
    .select("*") 
pd.read_sql(str(stmt), conn)
# Out:
# /tmp/ipykernel_8985/2052542231.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(str(stmt), conn)
# Empty DataFrame
# Columns: [id, sample_id, pipeline_version, run_id, task_name, task_exit_status, log]
# Index: []

# %%
tbl = Table("eval")
stmt = Query \
    .from_(tbl) \
    .select("*") 
pd.read_sql(str(stmt), conn)
# Out:
#     id dataset_id database  entrez_id srx_accession is_illumina  \
# 0    1      eval1      sra   35087715   SRX25994842         yes
# 1    2      eval1      sra   36178506   ERX11887200         yes
# 2    3      eval1      sra   30749595   SRX22716300         yes
# 3    4      eval1      sra   18060880   SRX13201194         yes
# 4    5      eval1      sra   36106630   SRX26727599         yes
# 5    6      eval1      sra   35979902   SRX26636208         yes
# 6    7      eval1      sra   35536066   SRX26313156         yes
# 7    8      eval1      sra   31054998   SRX22985325         yes
# 8    9      eval1      sra   35200088   SRX26085693         yes
# 9   10      eval1      sra   34439895    ERX9692805         yes
# 10  11      eval1      sra   33176418   SRX24842084         yes
# 11  12      eval1      sra   29115023   ERX11157721         yes
# 12  13      eval1      sra   32664033   SRX24349377         yes
# 13  14      eval1      sra    5920965    ERX2188110         yes
# 14  15      eval1      sra   35537624   SRX26314714          no
# 15  16      eval1      sra   36209780   SRX26798077         yes
# 16  17      eval1      sra   36280358   SRX26854925         yes
# 17  18      eval1      sra   31679394   SRX23448232         yes
# 18  19      eval1      gds  200281884           NaN          no
# 19  20      eval1      gds  200271457           NaN          no
# 20  21      eval1      gds  200277303   SRX26099173         yes
#
#    is_single_cell is_paired_end        lib_prep        tech_10x    organism  \
# 0             yes           yes    10X_Genomics     3_prime_gex       human
# 1             yes           yes    10X_Genomics     3_prime_gex       mouse
# 2             yes           yes    10X_Genomics     3_prime_gex       human
# 3              no            no  not_applicable  not_applicable       mouse
# 4              no           yes  not_applicable  not_applicable       mouse
# 5              no           yes  not_applicable  not_applicable       human
# 6              no           yes  not_applicable  not_applicable       human
# 7              no           yes  not_applicable  not_applicable       human
# 8             yes           yes           other  not_applicable     chicken
# 9             yes           yes           other     3_prime_gex     chicken
# 10            yes           yes           other     3_prime_gex   zebrafish
# 11            yes           yes           other     3_prime_gex   zebrafish
# 12            yes           yes           other     5_prime_gex     macaque
# 13            yes           yes           other           other     macaque
# 14            yes            no           other           other       human
# 15             no           yes  not_applicable  not_applicable       mouse
# 16             no           yes  not_applicable  not_applicable  metagenome
# 17             no           yes  not_applicable  not_applicable  metagenome
# 18             no            no  not_applicable  not_applicable       human
# 19             no            no  not_applicable  not_applicable       human
# 20             no            no  not_applicable  not_applicable       mouse
#
#          cell_prep
# 0      single_cell
# 1      single_cell
# 2      single_cell
# 3   not_applicable
# 4   not_applicable
# 5   not_applicable
# 6   not_applicable
# 7   not_applicable
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15  not_applicable
# 16  not_applicable
# 17  not_applicable
# 18  not_applicable
# 19  not_applicable
# 20  not_applicable

# %%
# filter to get unprocessed records
srx_metadata = Table("srx_metadata")
stmt = Query \
    .from_(srx_metadata) \
    .select("*") \
    .where((srx_metadata.processed != "complete") | (srx_metadata.processed.isnull())) \
    .where(srx_metadata.database == "sra")
pd.read_sql(str(stmt), conn)
# Out:
# /tmp/ipykernel_8985/2340524525.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(str(stmt), conn)
# Empty DataFrame
# Columns: [id, database, entrez_id, srx_accession, is_illumina, is_single_cell, is_paired_end, is_10x, tech_10x, organism, processed]
# Index: []

# %% [markdown]
# # Remove records

# %%
# remove from "srx_metadata" based on id column
record_id = 19
tbl = Table("srx_metadata")
stmt = Query \
    .from_(tbl) \
    .where(tbl.id == record_id) \
    .delete()
execute_query(stmt, conn)

# %% [markdown]
# # Add ground truth

# %%
df = pd.read_csv("../data/ground_truth1.csv")
df["dataset_id"] = "ground_truth1"
df.head()
# Out:
#   database  entrez_id          SRX is_illumina is_single_cell is_paired_end  \
# 0      sra   35087715  SRX25994842         yes            yes           yes
# 1      sra   36178506  ERX11887200         yes            yes           yes
# 2      sra   30749595  SRX22716300         yes            yes           yes
# 3      sra   18060880  SRX13201194         yes             no            no
# 4      sra   36106630  SRX26727599         yes             no           yes
#
#   is_10x     tech_10x organism     dataset_id
# 0    yes  3_prime_gex    human  ground_truth1
# 1    yes  3_prime_gex    mouse  ground_truth1
# 2    yes  3_prime_gex    human  ground_truth1
# 3     no        other    mouse  ground_truth1
# 4     no        other    mouse  ground_truth1

# %% [markdown]
# # Find blocking locks

# %%
query = """SELECT
    pid,
    usename,
    pg_blocking_pids(pid) AS blocked_by,
    state,
    query,
    NOW() - query_start AS duration
FROM pg_stat_activity
WHERE state != 'idle';
"""

PIDs = []
with conn.cursor() as cur:
    cur.execute(query)
    for x in cur.fetchall():
        PIDs.append(x[0])
PIDs
# Out:
# [244880]

# %%
query = "SELECT pg_terminate_backend({pid})"
with conn.cursor() as cur:
    for pid in PIDs:
        cur.execute(query.format(pid=pid))
        conn.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[33], line 4
#       2 with conn.cursor() as cur:
#       3     for pid in PIDs:
# ----> 4         cur.execute(query.format(pid=pid))
#       5         conn.commit()
#
# OperationalError: SSL connection has been closed unexpectedly
