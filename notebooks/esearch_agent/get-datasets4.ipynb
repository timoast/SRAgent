# %% [markdown]
# # Goals
#
# * Create a pipeline to gather new datasets from GEO and SRA

# %% [markdown]
# # Init

# %%
import os
import operator
from functools import partial
from pprint import pprint
from typing import Annotated, List, Dict, Tuple, Optional, Union, Any, TypedDict
from pydantic import BaseModel, Field
from Bio import Entrez
import pandas as pd
from dotenv import load_dotenv

# %%
from SRAgent.agents.entrez import create_entrez_agent
from SRAgent.agents.utils import create_step_summary_chain
from SRAgent.tools.convert import geo2sra

# %%
# setup
load_dotenv()
pd.set_option('display.max_colwidth', 1000)
os.environ["DEBUG_MODE"] = "TRUE"

# %%
# checks
if os.getenv("DEBUG_MODE") == "TRUE":
    print("DEBUG_MODE is enabled.")
# Out:
# DEBUG_MODE is enabled.

# %%
# set up Entrez
Entrez.email = "nick.youngblut@arcinstitute.org"
Entrez.api_key = os.getenv("NCBI_API_KEY")

# %% [markdown]
# # Entrez agent

# %%
# create entrez agent
entrez_agent = create_entrez_agent()
step_summary_chain = create_step_summary_chain()

# %%
# invoke agent
input = {"messages": [("user", "Convert GSE121737 to SRX accessions")]}
#invoke_entrez_agent(input, entrez_agent, step_summary_chain)

# %%
entrez_id = "35966237"
content = f"Obtain SRX accessions associated with Entrez ID {entrez_id}"
input = {"messages": [("user", content)]}
# invoke_entrez_agent(input, entrez_agent, step_summary_chain)

# %%
SRX_id = "SRX4967527"
content = f"Obtain SRR accessions associated with {SRX_id}"
input = {"messages": [("user", content)]}
# invoke_entrez_agent(input, entrez_agent, step_summary_chain)

# %% [markdown]
# # Graph

# %%
from langgraph.types import Send
from langchain_core.messages import BaseMessage, HumanMessage, AIMessage

# %%
from SRAgent.tools.esearch import esearch_scrna
from SRAgent.agents.convert import create_convert_graph, invoke_convert_graph
from SRAgent.agents.metadata import OrganismEnum, YesNo, create_metadata_graph, invoke_metadata_graph, get_metadata_items

# %%
class TopState(TypedDict):
    """
    Shared state of the agents in the graph
    """
    database: str
    # esearch IDs
    entrez_ids: List[str]
    # final entrez_id
    final_entrez_id: Annotated[List[str], operator.add]
    # accessions
    SRX: Annotated[List[List[str]], operator.add]
    SRP: Annotated[List[List[str]], operator.add]
    SRR: Annotated[List[List[str]], operator.add]
    # is_illumina
    is_illumina: Annotated[List[str], operator.add]
    # is_single_cell
    is_single_cell: Annotated[List[str], operator.add]
    # is_paired_end
    is_paired_end: Annotated[List[str], operator.add]
    # is_10x
    is_10x: Annotated[List[str], operator.add]
    # organism
    organism: Annotated[List[str], operator.add]

# %% [markdown]
# ## Nodes

# %%
def invoke_esearch(state: TopState):
    query = '("single cell RNA sequencing" OR "single cell RNA-seq")'
    entrez_ids = esearch_scrna.invoke({"esearch_query" : query, "database" : state["database"]})
    return {"entrez_ids" : entrez_ids}

# invoke_esearch({"database" : "gds", "entrez_ids" : []})

# %%
# create react agent
def invoke_sra2geo(state: TopState):
    """
    Invoke the geo2sra tool to get SRA accessions for a GEO dataset.
    """
    # invoke tool
    sra_ids = geo2sra.invoke({"entrez_ids" : state["entrez_ids"]})
    # update state
    return {"entrez_ids" : sra_ids}

# invoke_sra2geo({"entrez_ids" : ["200274955"]})

# %%
# ID conversion router
def id_convert_router(state: TopState):
    """
    Route the Entrez IDs to the appropriate conversion tool.
    """
    if state["database"] == "gds":
        return ["id_convert_node"]
    else:
        return ["id_agg_node"]

# %%
# aggregation node
def id_agg(state: TopState):
    """
    Aggregate IDs from various nodes
    """
    return {"database" : state["database"]}

# %%
# conversion subgraph
invoke_convert_graph_p = partial(
    invoke_convert_graph,
    graph = create_convert_graph(),
    to_return = ["final_entrez_id", "SRP", "SRX", "SRR"]
)

# %%
# Parallel invoke of the subgraph
def continue_to_conversion(state: TopState):
    # invoke the subgraph for each ID
    response = []
    for entrez_id in state["entrez_ids"]:
        input = {
            "final_entrez_id": entrez_id,
            "messages": [HumanMessage(
                f"Convert Entrez ID {entrez_id} to SRX accessions."
                " The Entrez ID is associated with the SRA database."
            )]}
        response.append(Send("convert_graph_node", input))
    return response

# %%
# metadata subgraph
invoke_metadata_graph_p = partial(
    invoke_metadata_graph,
    graph = create_metadata_graph()
)

# %%
# Parallel invoke of the subgraph
def continue_to_metadata(state: TopState):
    # format the prompt for the metadata graph
    prompt = "\n".join([
            "For the SRA accession {SRX_accession}, find the following information:",
            ] + get_metadata_items()
    )
    response = []
    # submit each accession to the metadata graph
    for SRP,SRX,SRR in zip(state["SRP"], state["SRX"], state["SRR"]):
        input = {
            "database": state["database"],
            "entrez_id": state["final_entrez_id"],
            "SRP": SRP,
            "SRX": SRX,
            "SRR": SRR,
            "messages": [HumanMessage(prompt.format(SRX_accession=SRX[0]))]
        }
        response.append(Send("metadata_graph_node", input))
    return response

# %%
def final_state(state: TopState):
    # return final state
    return {
        "database": state["database"],
        "entrez_ids": state["entrez_ids"],
        "SRP": state["SRP"],
        "SRX": state["SRX"],
        "SRR": state["SRR"],
        "is_illumina": state["is_illumina"],
        "is_single_cell": state["is_single_cell"],
        "is_paired_end": state["is_paired_end"],
        "is_10x": state["is_10x"],
        "organism": state["organism"]
    }

# %% [markdown]
# ## Compile

# %%
from langgraph.graph import START, END, StateGraph

# %%
#-- graph --#
workflow = StateGraph(TopState)

# nodes
workflow.add_node("esearch_node", invoke_esearch)
workflow.add_node("id_convert_node", invoke_sra2geo)
workflow.add_node("id_agg_node", id_agg)
workflow.add_node("convert_graph_node", invoke_convert_graph_p)
workflow.add_node("metadata_graph_node", invoke_metadata_graph_p)
workflow.add_node("final_state_node", final_state)

# edges
workflow.add_edge(START, "esearch_node")
workflow.add_conditional_edges("esearch_node", id_convert_router, ["id_convert_node", "id_agg_node"])
workflow.add_edge("id_convert_node", "id_agg_node")
workflow.add_conditional_edges("id_agg_node", continue_to_conversion, ["convert_graph_node"])
workflow.add_conditional_edges("convert_graph_node", continue_to_metadata, ["metadata_graph_node"])
workflow.add_edge("metadata_graph_node", "final_state_node")
workflow.add_edge("final_state_node", END)

# compile the graph
graph = workflow.compile()

# %%
from IPython.display import Image
Image(graph.get_graph().draw_mermaid_png())

# %%
# # Call the graph: SRA database
# final_state = None
# for step in graph.stream({"database": "sra"}, subgraphs=True, config={"max_concurrency" : 3, "recursion_limit": 200}):
#     print(step)
#     final_state = step
# print("---")
# print(final_state)

# %%
# Convert final state to a dataframe
#results = pd.DataFrame(final_state[1]['final_state_node'])
#results

# %% [markdown]
# #### GEO database

# %%
# Call the graph: GEO database
final_state = None
for step in graph.stream({"database": "gds"}, subgraphs=True, config={"max_concurrency" : 3, "recursion_limit": 200}):
    print(step)
    final_state = step
print("---")
print(final_state)
# Out:
# ((), {'esearch_node': {'entrez_ids': ['200282400']}})
# ((), {'id_convert_node': {'entrez_ids': ['36185246', '36185245']}})
# ((), {'id_agg_node': {'database': 'gds'}})
# (('convert_graph_node:103b3661-106c-fd01-4f61-124a7fd98100', 'entrez_agent_node:93c86849-f4f9-6955-a878-825b57ad5b88'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_G034CrLpMLXB9azjmbk8ZBI3', 'function': {'arguments': '{"message":"Fetch the SRA accessions for Entrez ID 36185245."}', 'name': 'invoke_efetch_worker'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 964, 'total_tokens': 995, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90354628f2', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-eeff8768-6964-4af0-9176-dfaa02e1812b-0', tool_calls=[{'name': 'invoke_efetch_worker', 'args': {'message': 'Fetch the SRA accessions for Entrez ID 36185245.'}, 'id': 'call_G034CrLpMLXB9azjmbk8ZBI3', 'type': 'tool_call'}], usage_metadata={'input_tokens': 964, 'output_tokens': 31, 'total_tokens': 995, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('convert_graph_node:a65113ea-3fe6-8ec6-bac1-eadd8a8ae8a3', 'entrez_agent_node:64cafc40-7f2f-8a78-8f86-8cbf18e3a3e5'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_lkfx8mz75BRClOKhcg4Yr38I', 'function': {'arguments': '{"message":"Fetch the SRA accessions for Entrez ID 36185246."}', 'name': 'invoke_efetch_worker'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 964, 'total_tokens': 995, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90354628f2', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-74e551f6-24d6-468b-a258-4aa75c38064c-0', tool_calls=[{'name': 'invoke_efetch_worker', 'args': {'message': 'Fetch the SRA accessions for Entrez ID 36185246.'}, 'id': 'call_lkfx8mz75BRClOKhcg4Yr38I', 'type': 'tool_call'}], usage_metadata={'input_tokens': 964, 'output_tokens': 31, 'total_tokens': 995, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('convert_graph_node:103b3661-106c-fd01-4f61-124a7fd98100', 'entrez_agent_node:93c86849-f4f9-6955-a878-825b57ad5b88', 'tools:a8c524c8-c5d4-f28b-9a41-1d6b953592cf'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_G034CrLpMLXB9azjmbk8ZBI3', 'function': {'arguments': '{"entrez_ids":["36185245"]}', 'name': 'which_entrez_databases'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 226, 'total_tokens': 248, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0705bf87c0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-f4c90093-5d86-4f7f-bef8-a7b6b70c8b82-0', tool_calls=[{'name': 'which_entrez_databases', 'args': {'entrez_ids': ['36185245']}, 'id': 'call_G034CrLpMLXB9azjmbk8ZBI3', 'type': 'tool_call'}], usage_metadata={'input_tokens': 226, 'output_tokens': 22, 'total_tokens': 248, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('convert_graph_node:a65113ea-3fe6-8ec6-bac1-eadd8a8ae8a3', 'entrez_agent_node:64cafc40-7f2f-8a78-8f86-8cbf18e3a3e5', 'tools:b35de105-e15c-4a6e-0da9-12a3de6bdfbf'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_4sCjSCN9gRACEZLVK4ooW2UV', 'function': {'arguments': '{"entrez_ids":["36185246"]}', 'name': 'which_entrez_databases'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 226, 'total_tokens': 248, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0705bf87c0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-08e1d5ec-6753-4242-a34d-c0b0436b8ea7-0', tool_calls=[{'name': 'which_entrez_databases', 'args': {'entrez_ids': ['36185246']}, 'id': 'call_4sCjSCN9gRACEZLVK4ooW2UV', 'type': 'tool_call'}], usage_metadata={'input_tokens': 226, 'output_tokens': 22, 'total_tokens': 248, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('convert_graph_node:103b3661-106c-fd01-4f61-124a7fd98100', 'entrez_agent_node:93c86849-f4f9-6955-a878-825b57ad5b88', 'tools:a8c524c8-c5d4-f28b-9a41-1d6b953592cf'), {'tools': {'messages': [ToolMessage(content='Entrez ID 36185245 found in: sra, pubmed.', name='which_entrez_databases', id='758da165-6605-40e0-95d3-16aa57fa26e6', tool_call_id='call_G034CrLpMLXB9azjmbk8ZBI3')]}})
# (('convert_graph_node:a65113ea-3fe6-8ec6-bac1-eadd8a8ae8a3', 'entrez_agent_node:64cafc40-7f2f-8a78-8f86-8cbf18e3a3e5', 'tools:b35de105-e15c-4a6e-0da9-12a3de6bdfbf'), {'tools': {'messages': [ToolMessage(content='Entrez ID 36185246 found in: sra, pubmed.', name='which_entrez_databases', id='ec73370a-a4ce-4bee-9551-11ac99b0b9a5', tool_call_id='call_4sCjSCN9gRACEZLVK4ooW2UV')]}})
# (('convert_graph_node:103b3661-106c-fd01-4f61-124a7fd98100', 'entrez_agent_node:93c86849-f4f9-6955-a878-825b57ad5b88', 'tools:a8c524c8-c5d4-f28b-9a41-1d6b953592cf'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_Q9gUybni61W56IRr9kSgazD9', 'function': {'arguments': '{"entrez_ids":["36185245"],"database":"sra"}', 'name': 'efetch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 275, 'total_tokens': 300, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0705bf87c0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-3921b7a5-d05f-41e7-abbf-d4dc53c6703d-0', tool_calls=[{'name': 'efetch', 'args': {'entrez_ids': ['36185245'], 'database': 'sra'}, 'id': 'call_Q9gUybni61W56IRr9kSgazD9', 'type': 'tool_call'}], usage_metadata={'input_tokens': 275, 'output_tokens': 25, 'total_tokens': 300, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('convert_graph_node:a65113ea-3fe6-8ec6-bac1-eadd8a8ae8a3', 'entrez_agent_node:64cafc40-7f2f-8a78-8f86-8cbf18e3a3e5', 'tools:b35de105-e15c-4a6e-0da9-12a3de6bdfbf'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_ze3t9kvvppyauL96CO1DbfI3', 'function': {'arguments': '{"entrez_ids":["36185246"],"database":"sra"}', 'name': 'efetch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 275, 'total_tokens': 300, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0705bf87c0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-c1cac83a-c52f-4394-80e4-cb7bcbaf8b0c-0', tool_calls=[{'name': 'efetch', 'args': {'entrez_ids': ['36185246'], 'database': 'sra'}, 'id': 'call_ze3t9kvvppyauL96CO1DbfI3', 'type': 'tool_call'}], usage_metadata={'input_tokens': 275, 'output_tokens': 25, 'total_tokens': 300, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('convert_graph_node:103b3661-106c-fd01-4f61-124a7fd98100', 'entrez_agent_node:93c86849-f4f9-6955-a878-825b57ad5b88', 'tools:a8c524c8-c5d4-f28b-9a41-1d6b953592cf'), {'tools': {'messages': [ToolMessage(content='{\n  "EXPERIMENT_PACKAGE_SET": {\n    "EXPERIMENT_PACKAGE": {\n      "EXPERIMENT": {\n        "@accession": "SRX26777129",\n        "@alias": "GSM8642547_r1",\n        "IDENTIFIERS": {\n          "PRIMARY_ID": "SRX26777129",\n          "EXTERNAL_ID": {\n            "@namespace": "GEO",\n            "#text": "GSM8642547_r1"\n          }\n        },\n        "TITLE": "GSM8642547: Day8_LPKO; Homo sapiens; RNA-Seq",\n        "STUDY_REF": {\n          "@accession": "SRP546381",\n          "IDENTIFIERS": {\n            "PRIMARY_ID": "SRP546381",\n            "EXTERNAL_ID": {\n              "@namespace": "GEO",\n              "#text": "GSE282400"\n            }\n          }\n        },\n        "DESIGN": {\n          "DESIGN_DESCRIPTION": null,\n          "SAMPLE_DESCRIPTOR": {\n            "@accession": "SRS23263888",\n            "IDENTIFIERS": {\n              "PRIMARY_ID": "SRS23263888",\n              "EXTERNAL_ID": {\n                "@namespace": "GEO",\n                "#text": "GSM8642547"\n              }\n            }\n          },\n          "LIBRARY_DESCRIPTOR": {\n            "LIBRARY_NAME": "GSM8642547",\n            "LIBRARY_STRATEGY": "RNA-Seq",\n            "LIBRARY_SOURCE": "TRANSCRIPTOMIC SINGLE CELL",\n            "LIBRARY_SELECTION": "cDNA",\n            "LIBRARY_LAYOUT": {\n              "PAIRED": null\n            },\n            "LIBRARY_CONSTRUCTION_PROTOCOL": "RNA was extracted using Rneasy mini (Qiagen) Librarys were constructed with NEBNext Ultra II RNA Library Prep Kit"\n          }\n        },\n        "PLATFORM": {\n          "ILLUMINA": {\n            "INSTRUMENT_MODEL": "Illumina NovaSeq 6000"\n          }\n        }\n      },\n      "SUBMISSION": {\n        "@lab_name": "",\n        "@center_name": "Luftig, Molecular Genetics and Microbiology, Duke University",\n        "@accession": "SRA2018112",\n        "@alias": "SUB14877922",\n        "IDENTIFIERS": {\n          "PRIMARY_ID": "SRA2018112",\n          "SUBMITTER_ID": {\n            "@namespace": "Luftig, Molecular Genetics and Microbiology, Duke University",\n            "#text": "SUB14877922"\n          }\n        }\n      },\n      "Organization": {\n        "@type": "institute",\n        "Name": "Luftig, Molecular Genetics and Microbiology, Duke University",\n        "Contact": {\n          "@email": "jana.cable@duke.edu",\n          "Address": {\n            "Street": "213 Research Dr.",\n            "City": "Durham",\n            "Sub": "NC",\n            "Country": "USA"\n          },\n          "Name": {\n            "First": "Jana",\n            "Last": "Cable"\n          }\n        }\n      },\n      "STUDY": {\n        "@center_name": "GEO",\n        "@alias": "GSE282400",\n        "@accession": "SRP546381",\n        "IDENTIFIERS": {\n          "PRIMARY_ID": "SRP546381",\n          "EXTERNAL_ID": [\n            {\n              "@namespace": "BioProject",\n              "@label": "primary",\n              "#text": "PRJNA1188499"\n            },\n            {\n              "@namespace": "GEO",\n              "#text": "GSE282400"\n            }\n          ]\n        },\n        "DESCRIPTOR": {\n          "STUDY_TITLE": "GEO accession GSE282400 is currently private and is scheduled to be released on Nov 25, 2024.",\n          "STUDY_TYPE": {\n            "@existing_study_type": "Transcriptome Analysis"\n          },\n          "STUDY_ABSTRACT": "If GEO accession GSE282400 has been cited in a publication, please notify us at geo@ncbi.nlm.nih.gov to initiate the public release of associated data.",\n          "CENTER_PROJECT_NAME": "GSE282400"\n        }\n      },\n      "SAMPLE": {\n        "@alias": "GSM8642547",\n        "@accession": "SRS23263888",\n        "IDENTIFIERS": {\n          "PRIMARY_ID": "SRS23263888",\n          "E ...
# (('convert_graph_node:a65113ea-3fe6-8ec6-bac1-eadd8a8ae8a3', 'entrez_agent_node:64cafc40-7f2f-8a78-8f86-8cbf18e3a3e5', 'tools:b35de105-e15c-4a6e-0da9-12a3de6bdfbf'), {'tools': {'messages': [ToolMessage(content='{\n  "EXPERIMENT_PACKAGE_SET": {\n    "EXPERIMENT_PACKAGE": {\n      "EXPERIMENT": {\n        "@accession": "SRX26777130",\n        "@alias": "GSM8642548_r1",\n        "IDENTIFIERS": {\n          "PRIMARY_ID": "SRX26777130",\n          "EXTERNAL_ID": {\n            "@namespace": "GEO",\n            "#text": "GSM8642548_r1"\n          }\n        },\n        "TITLE": "GSM8642548: Day8_WT; Homo sapiens; RNA-Seq",\n        "STUDY_REF": {\n          "@accession": "SRP546381",\n          "IDENTIFIERS": {\n            "PRIMARY_ID": "SRP546381",\n            "EXTERNAL_ID": {\n              "@namespace": "GEO",\n              "#text": "GSE282400"\n            }\n          }\n        },\n        "DESIGN": {\n          "DESIGN_DESCRIPTION": null,\n          "SAMPLE_DESCRIPTOR": {\n            "@accession": "SRS23263889",\n            "IDENTIFIERS": {\n              "PRIMARY_ID": "SRS23263889",\n              "EXTERNAL_ID": {\n                "@namespace": "GEO",\n                "#text": "GSM8642548"\n              }\n            }\n          },\n          "LIBRARY_DESCRIPTOR": {\n            "LIBRARY_NAME": "GSM8642548",\n            "LIBRARY_STRATEGY": "RNA-Seq",\n            "LIBRARY_SOURCE": "TRANSCRIPTOMIC SINGLE CELL",\n            "LIBRARY_SELECTION": "cDNA",\n            "LIBRARY_LAYOUT": {\n              "PAIRED": null\n            },\n            "LIBRARY_CONSTRUCTION_PROTOCOL": "RNA was extracted using Rneasy mini (Qiagen) Librarys were constructed with NEBNext Ultra II RNA Library Prep Kit"\n          }\n        },\n        "PLATFORM": {\n          "ILLUMINA": {\n            "INSTRUMENT_MODEL": "Illumina NovaSeq 6000"\n          }\n        }\n      },\n      "SUBMISSION": {\n        "@lab_name": "",\n        "@center_name": "Luftig, Molecular Genetics and Microbiology, Duke University",\n        "@accession": "SRA2018112",\n        "@alias": "SUB14877922",\n        "IDENTIFIERS": {\n          "PRIMARY_ID": "SRA2018112",\n          "SUBMITTER_ID": {\n            "@namespace": "Luftig, Molecular Genetics and Microbiology, Duke University",\n            "#text": "SUB14877922"\n          }\n        }\n      },\n      "Organization": {\n        "@type": "institute",\n        "Name": "Luftig, Molecular Genetics and Microbiology, Duke University",\n        "Contact": {\n          "@email": "jana.cable@duke.edu",\n          "Address": {\n            "Street": "213 Research Dr.",\n            "City": "Durham",\n            "Sub": "NC",\n            "Country": "USA"\n          },\n          "Name": {\n            "First": "Jana",\n            "Last": "Cable"\n          }\n        }\n      },\n      "STUDY": {\n        "@center_name": "GEO",\n        "@alias": "GSE282400",\n        "@accession": "SRP546381",\n        "IDENTIFIERS": {\n          "PRIMARY_ID": "SRP546381",\n          "EXTERNAL_ID": [\n            {\n              "@namespace": "BioProject",\n              "@label": "primary",\n              "#text": "PRJNA1188499"\n            },\n            {\n              "@namespace": "GEO",\n              "#text": "GSE282400"\n            }\n          ]\n        },\n        "DESCRIPTOR": {\n          "STUDY_TITLE": "GEO accession GSE282400 is currently private and is scheduled to be released on Nov 25, 2024.",\n          "STUDY_TYPE": {\n            "@existing_study_type": "Transcriptome Analysis"\n          },\n          "STUDY_ABSTRACT": "If GEO accession GSE282400 has been cited in a publication, please notify us at geo@ncbi.nlm.nih.gov to initiate the public release of associated data.",\n          "CENTER_PROJECT_NAME": "GSE282400"\n        }\n      },\n      "SAMPLE": {\n        "@alias": "GSM8642548",\n        "@accession": "SRS23263889",\n        "IDENTIFIERS": {\n          "PRIMARY_ID": "SRS23263889",\n          "EXT ...
# (('convert_graph_node:a65113ea-3fe6-8ec6-bac1-eadd8a8ae8a3', 'entrez_agent_node:64cafc40-7f2f-8a78-8f86-8cbf18e3a3e5', 'tools:b35de105-e15c-4a6e-0da9-12a3de6bdfbf'), {'agent': {'messages': [AIMessage(content='- **Entrez ID**: 36185246\n- **SRA Accessions**:\n  - **SRX26777130**\n    - **Study Accession**: SRP546381\n    - **Sample Accession**: SRS23263889\n  - **Runs**:\n    - **SRR31408046**\n      - **Total Spots**: 159,456,105\n      - **Total Bases**: 20,250,925,335\n      - **Files**:\n        - [I1 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408046/1301_Day8_WT_S6_L001_I1_001.fastq.gz)\n        - [R1 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408046/1301_Day8_WT_S6_L001_R1_001.fastq.gz)\n        - [R2 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408046/1301_Day8_WT_S6_L001_R2_001.fastq.gz)\n    - **SRR31408047**\n      - **Total Spots**: 158,887,821\n      - **Total Bases**: 20,178,753,267\n      - **Files**:\n        - [I1 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408047/1301_Day8_WT_S6_L002_I1_001.fastq.gz)\n        - [R1 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408047/1301_Day8_WT_S6_L002_R1_001.fastq.gz)\n        - [R2 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408047/1301_Day8_WT_S6_L002_R2_001.fastq.gz)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 495, 'prompt_tokens': 6091, 'total_tokens': 6586, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 6016}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0705bf87c0', 'finish_reason': 'stop', 'logprobs': None}, id='run-97747e75-edbc-4c6d-8959-d1ff7bedadbf-0', usage_metadata={'input_tokens': 6091, 'output_tokens': 495, 'total_tokens': 6586, 'input_token_details': {'audio': 0, 'cache_read': 6016}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('convert_graph_node:a65113ea-3fe6-8ec6-bac1-eadd8a8ae8a3', 'entrez_agent_node:64cafc40-7f2f-8a78-8f86-8cbf18e3a3e5'), {'tools': {'messages': [ToolMessage(content="{'messages': [HumanMessage(content='- **Entrez ID**: 36185246\\n- **SRA Accessions**:\\n  - **SRX26777130**\\n    - **Study Accession**: SRP546381\\n    - **Sample Accession**: SRS23263889\\n  - **Runs**:\\n    - **SRR31408046**\\n      - **Total Spots**: 159,456,105\\n      - **Total Bases**: 20,250,925,335\\n      - **Files**:\\n        - [I1 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408046/1301_Day8_WT_S6_L001_I1_001.fastq.gz)\\n        - [R1 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408046/1301_Day8_WT_S6_L001_R1_001.fastq.gz)\\n        - [R2 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408046/1301_Day8_WT_S6_L001_R2_001.fastq.gz)\\n    - **SRR31408047**\\n      - **Total Spots**: 158,887,821\\n      - **Total Bases**: 20,178,753,267\\n      - **Files**:\\n        - [I1 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408047/1301_Day8_WT_S6_L002_I1_001.fastq.gz)\\n        - [R1 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408047/1301_Day8_WT_S6_L002_R1_001.fastq.gz)\\n        - [R2 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408047/1301_Day8_WT_S6_L002_R2_001.fastq.gz)', additional_kwargs={}, response_metadata={}, name='efetch worker')]}", name='invoke_efetch_worker', id='cda665a1-7fc5-438f-8844-9365edf8e13f', tool_call_id='call_lkfx8mz75BRClOKhcg4Yr38I')]}})
# (('convert_graph_node:103b3661-106c-fd01-4f61-124a7fd98100', 'entrez_agent_node:93c86849-f4f9-6955-a878-825b57ad5b88', 'tools:a8c524c8-c5d4-f28b-9a41-1d6b953592cf'), {'agent': {'messages': [AIMessage(content='- **Entrez ID**: 36185245\n- **SRA Accessions**:\n  - **SRX26777129**\n    - **Study Accession**: SRP546381\n    - **Sample Accession**: SRS23263888\n  - **Runs**:\n    - **SRR31408048**\n      - **Alias**: GSM8642547_r1\n      - **Total Spots**: 159,773,522\n      - **Total Bases**: 20,291,237,294\n      - **Files**:\n        - [I1 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408048/1301_Day8_LPKO_S7_L001_I1_001.fastq.gz)\n        - [R1 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408048/1301_Day8_LPKO_S7_L001_R1_001.fastq.gz)\n        - [R2 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408048/1301_Day8_LPKO_S7_L001_R2_001.fastq.gz)\n    - **SRR31408049**\n      - **Alias**: GSM8642547_r2\n      - **Total Spots**: 159,127,597\n      - **Total Bases**: 20,209,204,819\n      - **Files**:\n        - [I1 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408049/1301_Day8_LPKO_S7_L002_I1_001.fastq.gz)\n        - [R1 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408049/1301_Day8_LPKO_S7_L002_R1_001.fastq.gz)\n        - [R2 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408049/1301_Day8_LPKO_S7_L002_R2_001.fastq.gz)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 527, 'prompt_tokens': 5925, 'total_tokens': 6452, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 5760}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0705bf87c0', 'finish_reason': 'stop', 'logprobs': None}, id='run-fc477e0b-6342-4246-aaa1-e28eef10a7e8-0', usage_metadata={'input_tokens': 5925, 'output_tokens': 527, 'total_tokens': 6452, 'input_token_details': {'audio': 0, 'cache_read': 5760}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('convert_graph_node:103b3661-106c-fd01-4f61-124a7fd98100', 'entrez_agent_node:93c86849-f4f9-6955-a878-825b57ad5b88'), {'tools': {'messages': [ToolMessage(content="{'messages': [HumanMessage(content='- **Entrez ID**: 36185245\\n- **SRA Accessions**:\\n  - **SRX26777129**\\n    - **Study Accession**: SRP546381\\n    - **Sample Accession**: SRS23263888\\n  - **Runs**:\\n    - **SRR31408048**\\n      - **Alias**: GSM8642547_r1\\n      - **Total Spots**: 159,773,522\\n      - **Total Bases**: 20,291,237,294\\n      - **Files**:\\n        - [I1 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408048/1301_Day8_LPKO_S7_L001_I1_001.fastq.gz)\\n        - [R1 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408048/1301_Day8_LPKO_S7_L001_R1_001.fastq.gz)\\n        - [R2 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408048/1301_Day8_LPKO_S7_L001_R2_001.fastq.gz)\\n    - **SRR31408049**\\n      - **Alias**: GSM8642547_r2\\n      - **Total Spots**: 159,127,597\\n      - **Total Bases**: 20,209,204,819\\n      - **Files**:\\n        - [I1 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408049/1301_Day8_LPKO_S7_L002_I1_001.fastq.gz)\\n        - [R1 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408049/1301_Day8_LPKO_S7_L002_R1_001.fastq.gz)\\n        - [R2 Fastq](https://sra-download.be-md.ncbi.nlm.nih.gov/vast/sra01/SRZ/031408/SRR31408049/1301_Day8_LPKO_S7_L002_R2_001.fastq.gz)', additional_kwargs={}, response_metadata={}, name='efetch worker')]}", name='invoke_efetch_worker', id='db6714c6-26ba-4898-a31b-8d2967b688f0', tool_call_id='call_G034CrLpMLXB9azjmbk8ZBI3')]}})
# (('convert_graph_node:a65113ea-3fe6-8ec6-bac1-eadd8a8ae8a3', 'entrez_agent_node:64cafc40-7f2f-8a78-8f86-8cbf18e3a3e5'), {'agent': {'messages': [AIMessage(content='The Entrez ID 36185246 corresponds to the following SRX accession:\n\n- **SRX26777130**\n  - **Study Accession**: SRP546381\n  - **Sample Accession**: SRS23263889\n\nAssociated runs:\n- **SRR31408046**\n- **SRR31408047**', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 71, 'prompt_tokens': 1536, 'total_tokens': 1607, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90354628f2', 'finish_reason': 'stop', 'logprobs': None}, id='run-1d0c7521-5520-49ce-a7e9-23477caec23b-0', usage_metadata={'input_tokens': 1536, 'output_tokens': 71, 'total_tokens': 1607, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('convert_graph_node:a65113ea-3fe6-8ec6-bac1-eadd8a8ae8a3',), {'entrez_agent_node': {'messages': [AIMessage(content='The Entrez ID 36185246 corresponds to the following SRX accession:\n\n- **SRX26777130**\n  - **Study Accession**: SRP546381\n  - **Sample Accession**: SRS23263889\n\nAssociated runs:\n- **SRR31408046**\n- **SRR31408047**', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 71, 'prompt_tokens': 1536, 'total_tokens': 1607, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90354628f2', 'finish_reason': 'stop', 'logprobs': None}, id='run-1d0c7521-5520-49ce-a7e9-23477caec23b-0', usage_metadata={'input_tokens': 1536, 'output_tokens': 71, 'total_tokens': 1607, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('convert_graph_node:103b3661-106c-fd01-4f61-124a7fd98100', 'entrez_agent_node:93c86849-f4f9-6955-a878-825b57ad5b88'), {'agent': {'messages': [AIMessage(content='The Entrez ID 36185245 corresponds to the following SRX accession:\n\n- **SRX26777129**\n\nThis SRX accession is part of the study SRP546381 and sample SRS23263888.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 1568, 'total_tokens': 1614, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1408}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90354628f2', 'finish_reason': 'stop', 'logprobs': None}, id='run-5ee4dc3f-4408-4c5a-a237-a7bb228025e1-0', usage_metadata={'input_tokens': 1568, 'output_tokens': 46, 'total_tokens': 1614, 'input_token_details': {'audio': 0, 'cache_read': 1408}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('convert_graph_node:103b3661-106c-fd01-4f61-124a7fd98100',), {'entrez_agent_node': {'messages': [AIMessage(content='The Entrez ID 36185245 corresponds to the following SRX accession:\n\n- **SRX26777129**\n\nThis SRX accession is part of the study SRP546381 and sample SRS23263888.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 1568, 'total_tokens': 1614, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1408}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90354628f2', 'finish_reason': 'stop', 'logprobs': None}, id='run-5ee4dc3f-4408-4c5a-a237-a7bb228025e1-0', usage_metadata={'input_tokens': 1568, 'output_tokens': 46, 'total_tokens': 1614, 'input_token_details': {'audio': 0, 'cache_read': 1408}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('convert_graph_node:a65113ea-3fe6-8ec6-bac1-eadd8a8ae8a3',), {'get_accessions_node': {'SRP': ['SRP546381'], 'SRX': ['SRX26777130'], 'SRR': ['SRR31408046', 'SRR31408047']}})
# (('convert_graph_node:103b3661-106c-fd01-4f61-124a7fd98100',), {'get_accessions_node': {'SRP': ['SRP546381'], 'SRX': ['SRX26777129'], 'SRR': []}})
# (('convert_graph_node:a65113ea-3fe6-8ec6-bac1-eadd8a8ae8a3',), {'router_node': {'messages': [AIMessage(content='The SRX accession SRX26777130 has been successfully obtained from the Entrez ID 36185246.', additional_kwargs={}, response_metadata={})], 'route': 'Stop', 'rounds': 1}})
# ((), {'convert_graph_node': {'final_entrez_id': ['36185246'], 'SRX': [['SRX26777130']], 'SRP': [['SRP546381']], 'SRR': [['SRR31408046', 'SRR31408047']]}})
# (('convert_graph_node:103b3661-106c-fd01-4f61-124a7fd98100',), {'router_node': {'messages': [AIMessage(content='The SRX accession SRX26777129 has been successfully obtained from the Entrez ID 36185245.', additional_kwargs={}, response_metadata={})], 'route': 'Stop', 'rounds': 1}})
# ((), {'convert_graph_node': {'final_entrez_id': ['36185245'], 'SRX': [['SRX26777129']], 'SRP': [['SRP546381']], 'SRR': [[]]}})
# (('metadata_graph_node:73c298d1-b9ab-0398-ea8b-32eda584837d', 'entrez_agent_node:691315c3-a438-46da-b16c-30c6792d438e'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_myVH4wFPMBJM4zGSEVlhbLY0', 'function': {'arguments': '{"message":"Search SRA for SRX26777129 to obtain the Entrez ID."}', 'name': 'invoke_esearch_worker'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 1012, 'total_tokens': 1043, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90354628f2', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-b4c59606-1280-4f9b-8411-48112d2b0165-0', tool_calls=[{'name': 'invoke_esearch_worker', 'args': {'message': 'Search SRA for SRX26777129 to obtain the Entrez ID.'}, 'id': 'call_myVH4wFPMBJM4zGSEVlhbLY0', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1012, 'output_tokens': 31, 'total_tokens': 1043, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('metadata_graph_node:fca6da02-8804-2c8b-3c9c-833f0074e84f', 'entrez_agent_node:e4b980a8-9b12-a9b7-26cc-a455e1063b1e'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_fLvJv85qIpBTkv6ISe57n116', 'function': {'arguments': '{"message":"Search for SRX26777130 in the SRA database to obtain the Entrez ID."}', 'name': 'invoke_esearch_worker'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 1012, 'total_tokens': 1046, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90354628f2', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7d14b7a2-a0ee-4065-894f-7656c804d239-0', tool_calls=[{'name': 'invoke_esearch_worker', 'args': {'message': 'Search for SRX26777130 in the SRA database to obtain the Entrez ID.'}, 'id': 'call_fLvJv85qIpBTkv6ISe57n116', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1012, 'output_tokens': 34, 'total_tokens': 1046, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('metadata_graph_node:73c298d1-b9ab-0398-ea8b-32eda584837d', 'entrez_agent_node:691315c3-a438-46da-b16c-30c6792d438e', 'tools:04f70474-437e-5dca-1826-3aef3584e593'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_QNzCDwU8hU5VvG3DSsQ3EEnU', 'function': {'arguments': '{"esearch_query":"SRX26777129","database":"sra"}', 'name': 'esearch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 253, 'total_tokens': 278, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0705bf87c0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-bd208abc-c01b-4757-8624-1c419bc7a113-0', tool_calls=[{'name': 'esearch', 'args': {'esearch_query': 'SRX26777129', 'database': 'sra'}, 'id': 'call_QNzCDwU8hU5VvG3DSsQ3EEnU', 'type': 'tool_call'}], usage_metadata={'input_tokens': 253, 'output_tokens': 25, 'total_tokens': 278, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('metadata_graph_node:fca6da02-8804-2c8b-3c9c-833f0074e84f', 'entrez_agent_node:e4b980a8-9b12-a9b7-26cc-a455e1063b1e', 'tools:77f6263c-c75f-6031-564e-e8711e046bb4'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_387Z685THQfYAbIe4wyPvSVH', 'function': {'arguments': '{"esearch_query":"SRX26777130","database":"sra"}', 'name': 'esearch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 256, 'total_tokens': 281, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0705bf87c0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-24210a71-0f6b-4517-a237-e115b8f4d8ed-0', tool_calls=[{'name': 'esearch', 'args': {'esearch_query': 'SRX26777130', 'database': 'sra'}, 'id': 'call_387Z685THQfYAbIe4wyPvSVH', 'type': 'tool_call'}], usage_metadata={'input_tokens': 256, 'output_tokens': 25, 'total_tokens': 281, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('metadata_graph_node:73c298d1-b9ab-0398-ea8b-32eda584837d', 'entrez_agent_node:691315c3-a438-46da-b16c-30c6792d438e', 'tools:04f70474-437e-5dca-1826-3aef3584e593'), {'tools': {'messages': [ToolMessage(content='["{\'Count\': \'1\', \'IdList\': [\'36185245\'], \'TranslationSet\': [], \'TranslationStack\': [{\'Term\': \'SRX26777129[All Fields]\', \'Field\': \'All Fields\', \'Count\': \'1\', \'Explode\': \'N\'}, \'GROUP\'], \'QueryTranslation\': \'SRX26777129[All Fields]\'}"]', name='esearch', id='69eee326-3b03-4dc1-9bf2-576ae21ba447', tool_call_id='call_QNzCDwU8hU5VvG3DSsQ3EEnU')]}})
# (('metadata_graph_node:fca6da02-8804-2c8b-3c9c-833f0074e84f', 'entrez_agent_node:e4b980a8-9b12-a9b7-26cc-a455e1063b1e', 'tools:77f6263c-c75f-6031-564e-e8711e046bb4'), {'tools': {'messages': [ToolMessage(content='["{\'Count\': \'1\', \'IdList\': [\'36185246\'], \'TranslationSet\': [], \'TranslationStack\': [{\'Term\': \'SRX26777130[All Fields]\', \'Field\': \'All Fields\', \'Count\': \'1\', \'Explode\': \'N\'}, \'GROUP\'], \'QueryTranslation\': \'SRX26777130[All Fields]\'}"]', name='esearch', id='f96de7cd-1e2a-4eec-81c4-30e8c4391255', tool_call_id='call_387Z685THQfYAbIe4wyPvSVH')]}})
# (('metadata_graph_node:73c298d1-b9ab-0398-ea8b-32eda584837d', 'entrez_agent_node:691315c3-a438-46da-b16c-30c6792d438e', 'tools:04f70474-437e-5dca-1826-3aef3584e593'), {'agent': {'messages': [AIMessage(content='- Entrez ID for SRX26777129: 36185245', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 363, 'total_tokens': 379, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0705bf87c0', 'finish_reason': 'stop', 'logprobs': None}, id='run-6f6b7508-4b4d-49c2-8585-25b91fea8ebd-0', usage_metadata={'input_tokens': 363, 'output_tokens': 16, 'total_tokens': 379, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('metadata_graph_node:73c298d1-b9ab-0398-ea8b-32eda584837d', 'entrez_agent_node:691315c3-a438-46da-b16c-30c6792d438e'), {'tools': {'messages': [ToolMessage(content="{'messages': [HumanMessage(content='- Entrez ID for SRX26777129: 36185245', additional_kwargs={}, response_metadata={}, name='esearch worker')]}", name='invoke_esearch_worker', id='fe827fb7-40c9-4365-ab24-78a8cb12d3fa', tool_call_id='call_myVH4wFPMBJM4zGSEVlhbLY0')]}})
# (('metadata_graph_node:fca6da02-8804-2c8b-3c9c-833f0074e84f', 'entrez_agent_node:e4b980a8-9b12-a9b7-26cc-a455e1063b1e', 'tools:77f6263c-c75f-6031-564e-e8711e046bb4'), {'agent': {'messages': [AIMessage(content='- Entrez ID for SRX26777130: 36185246', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 366, 'total_tokens': 382, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0705bf87c0', 'finish_reason': 'stop', 'logprobs': None}, id='run-1b01e845-fa07-440f-8296-e779bcdc3be0-0', usage_metadata={'input_tokens': 366, 'output_tokens': 16, 'total_tokens': 382, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('metadata_graph_node:fca6da02-8804-2c8b-3c9c-833f0074e84f', 'entrez_agent_node:e4b980a8-9b12-a9b7-26cc-a455e1063b1e'), {'tools': {'messages': [ToolMessage(content="{'messages': [HumanMessage(content='- Entrez ID for SRX26777130: 36185246', additional_kwargs={}, response_metadata={}, name='esearch worker')]}", name='invoke_esearch_worker', id='d8f39f25-36de-4a34-af0d-ca152e609f1c', tool_call_id='call_fLvJv85qIpBTkv6ISe57n116')]}})
# (('metadata_graph_node:73c298d1-b9ab-0398-ea8b-32eda584837d', 'entrez_agent_node:691315c3-a438-46da-b16c-30c6792d438e'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_Bck4DMVpkLuNOtfXT7lfoIl2', 'function': {'arguments': '{"message":"Fetch details for Entrez ID 36185245 to determine if the study is Illumina sequence data, single cell RNA-seq data, paired-end sequencing data, 10X Genomics data, and the organism sequenced."}', 'name': 'invoke_efetch_worker'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 1090, 'total_tokens': 1153, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90354628f2', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-f380d978-a344-48f7-8c6e-9c6f1bc20497-0', tool_calls=[{'name': 'invoke_efetch_worker', 'args': {'message': 'Fetch details for Entrez ID 36185245 to determine if the study is Illumina sequence data, single cell RNA-seq data, paired-end sequencing data, 10X Genomics data, and the organism sequenced.'}, 'id': 'call_Bck4DMVpkLuNOtfXT7lfoIl2', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1090, 'output_tokens': 63, 'total_tokens': 1153, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('metadata_graph_node:fca6da02-8804-2c8b-3c9c-833f0074e84f', 'entrez_agent_node:e4b980a8-9b12-a9b7-26cc-a455e1063b1e'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_gUZHDMiZJ5QDI61n37TNrX2x', 'function': {'arguments': '{"message":"Fetch details for Entrez ID 36185246 to determine if the study is Illumina sequence data, single cell RNA-seq data, paired-end sequencing data, 10X Genomics data, and the organism sequenced."}', 'name': 'invoke_efetch_worker'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 1093, 'total_tokens': 1156, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90354628f2', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-e0f1eb62-fbb1-4047-80ed-a95bb5b3641a-0', tool_calls=[{'name': 'invoke_efetch_worker', 'args': {'message': 'Fetch details for Entrez ID 36185246 to determine if the study is Illumina sequence data, single cell RNA-seq data, paired-end sequencing data, 10X Genomics data, and the organism sequenced.'}, 'id': 'call_gUZHDMiZJ5QDI61n37TNrX2x', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1093, 'output_tokens': 63, 'total_tokens': 1156, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('metadata_graph_node:73c298d1-b9ab-0398-ea8b-32eda584837d', 'entrez_agent_node:691315c3-a438-46da-b16c-30c6792d438e', 'tools:1beb4b8f-844e-14e8-225d-83fdb7727520'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_1HxbtXYME6UuaLPUT0PP2bh4', 'function': {'arguments': '{"entrez_ids":["36185245"]}', 'name': 'which_entrez_databases'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 258, 'total_tokens': 280, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0705bf87c0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-acc097ba-0a01-4053-9ec6-3dc655247605-0', tool_calls=[{'name': 'which_entrez_databases', 'args': {'entrez_ids': ['36185245']}, 'id': 'call_1HxbtXYME6UuaLPUT0PP2bh4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 258, 'output_tokens': 22, 'total_tokens': 280, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('metadata_graph_node:fca6da02-8804-2c8b-3c9c-833f0074e84f', 'entrez_agent_node:e4b980a8-9b12-a9b7-26cc-a455e1063b1e', 'tools:9b495ace-cdc1-c777-3ee6-958252e3ae20'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_6R7WVJJeUBDNSg6XukfZ660s', 'function': {'arguments': '{"entrez_ids":["36185246"]}', 'name': 'which_entrez_databases'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 258, 'total_tokens': 280, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0705bf87c0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-c8f53b85-2dfc-4201-a8a5-f2011fb94a6a-0', tool_calls=[{'name': 'which_entrez_databases', 'args': {'entrez_ids': ['36185246']}, 'id': 'call_6R7WVJJeUBDNSg6XukfZ660s', 'type': 'tool_call'}], usage_metadata={'input_tokens': 258, 'output_tokens': 22, 'total_tokens': 280, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('metadata_graph_node:73c298d1-b9ab-0398-ea8b-32eda584837d', 'entrez_agent_node:691315c3-a438-46da-b16c-30c6792d438e', 'tools:1beb4b8f-844e-14e8-225d-83fdb7727520'), {'tools': {'messages': [ToolMessage(content='Entrez ID 36185245 found in: sra, pubmed.', name='which_entrez_databases', id='ae19d90c-4041-4c68-acff-976e5a610945', tool_call_id='call_1HxbtXYME6UuaLPUT0PP2bh4')]}})
# (('metadata_graph_node:fca6da02-8804-2c8b-3c9c-833f0074e84f', 'entrez_agent_node:e4b980a8-9b12-a9b7-26cc-a455e1063b1e', 'tools:9b495ace-cdc1-c777-3ee6-958252e3ae20'), {'tools': {'messages': [ToolMessage(content='Entrez ID 36185246 found in: sra, pubmed.', name='which_entrez_databases', id='aaecb863-a4fb-4d89-9261-6ee2f734b4aa', tool_call_id='call_6R7WVJJeUBDNSg6XukfZ660s')]}})
# (('metadata_graph_node:fca6da02-8804-2c8b-3c9c-833f0074e84f', 'entrez_agent_node:e4b980a8-9b12-a9b7-26cc-a455e1063b1e', 'tools:9b495ace-cdc1-c777-3ee6-958252e3ae20'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_hAliEdYkww6Dar1cFuqSAR8o', 'function': {'arguments': '{"entrez_ids": ["36185246"], "database": "sra"}', 'name': 'efetch'}, 'type': 'function'}, {'id': 'call_H22y6TudoVrqP1SeG8STJn0Y', 'function': {'arguments': '{"entrez_ids": ["36185246"], "database": "pubmed"}', 'name': 'efetch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 307, 'total_tokens': 373, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0705bf87c0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-97b25510-bf23-4082-93d2-2ebaf6df9150-0', tool_calls=[{'name': 'efetch', 'args': {'entrez_ids': ['36185246'], 'database': 'sra'}, 'id': 'call_hAliEdYkww6Dar1cFuqSAR8o', 'type': 'tool_call'}, {'name': 'efetch', 'args': {'entrez_ids': ['36185246'], 'database': 'pubmed'}, 'id': 'call_H22y6TudoVrqP1SeG8STJn0Y', 'type': 'tool_call'}], usage_metadata={'input_tokens': 307, 'output_tokens': 66, 'total_tokens': 373, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# ...
# (('metadata_graph_node:fca6da02-8804-2c8b-3c9c-833f0074e84f', 'entrez_agent_node:e4b980a8-9b12-a9b7-26cc-a455e1063b1e', 'tools:9b495ace-cdc1-c777-3ee6-958252e3ae20'), {'agent': {'messages': [AIMessage(content='- **Entrez ID**: 36185246\n- **Organism**: Homo sapiens (Human)\n- **Study Type**: RNA-Seq\n- **Sequencing Platform**: Illumina NovaSeq 6000\n- **Library Source**: Transcriptomic Single Cell\n- **Library Selection**: cDNA\n- **Paired-End Sequencing**: Yes (indicated by the absence of paired layout null)\n- **10X Genomics Data**: Not specified (data is from Illumina)\n- **Study Title**: A stratification system of ferroptosis and iron-metabolism related LncRNAs guides the prediction of the survival of patients with esophageal squamous cell carcinoma.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 149, 'prompt_tokens': 12176, 'total_tokens': 12325, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0705bf87c0', 'finish_reason': 'stop', 'logprobs': None}, id='run-0f8525b1-73ff-4e95-9078-b2b4104e5eaf-0', usage_metadata={'input_tokens': 12176, 'output_tokens': 149, 'total_tokens': 12325, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('metadata_graph_node:fca6da02-8804-2c8b-3c9c-833f0074e84f', 'entrez_agent_node:e4b980a8-9b12-a9b7-26cc-a455e1063b1e'), {'tools': {'messages': [ToolMessage(content="{'messages': [HumanMessage(content='- **Entrez ID**: 36185246\\n- **Organism**: Homo sapiens (Human)\\n- **Study Type**: RNA-Seq\\n- **Sequencing Platform**: Illumina NovaSeq 6000\\n- **Library Source**: Transcriptomic Single Cell\\n- **Library Selection**: cDNA\\n- **Paired-End Sequencing**: Yes (indicated by the absence of paired layout null)\\n- **10X Genomics Data**: Not specified (data is from Illumina)\\n- **Study Title**: A stratification system of ferroptosis and iron-metabolism related LncRNAs guides the prediction of the survival of patients with esophageal squamous cell carcinoma.', additional_kwargs={}, response_metadata={}, name='efetch worker')]}", name='invoke_efetch_worker', id='67adc5fa-3399-4e3f-b152-095fa3293dad', tool_call_id='call_gUZHDMiZJ5QDI61n37TNrX2x')]}})
# (('metadata_graph_node:73c298d1-b9ab-0398-ea8b-32eda584837d', 'entrez_agent_node:691315c3-a438-46da-b16c-30c6792d438e', 'tools:1beb4b8f-844e-14e8-225d-83fdb7727520'), {'agent': {'messages': [AIMessage(content='- **Entrez ID**: 36185245\n- **Study Information**:\n  - **Title**: Differentiation of glioblastoma tissues using spontaneous Raman scattering with dimensionality reduction and data classification.\n  - **Journal**: Frontiers in Oncology\n  - **Publication Date**: October 4, 2022\n  - **Authors**: Igor Romanishkin et al.\n  \n- **Sequencing Details**:\n  - **Organism**: Homo sapiens\n  - **Library Strategy**: RNA-Seq\n  - **Library Source**: Transcriptomic Single Cell\n  - **Library Selection**: cDNA\n  - **Platform**: Illumina NovaSeq 6000\n  - **Paired-End Sequencing**: Yes (indicated by the library layout)\n  - **Single Cell RNA-seq**: Yes (indicated by the library source)\n  - **10X Genomics Data**: Not specified, but the study involves single-cell RNA-seq which may utilize similar technologies.\n\n- **Additional Notes**:\n  - The study focuses on the application of Raman spectroscopy for differentiating glioblastoma tissues, which is not directly related to sequencing but indicates a multi-faceted approach to understanding tumor biology.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 261, 'prompt_tokens': 10297, 'total_tokens': 10558, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0705bf87c0', 'finish_reason': 'stop', 'logprobs': None}, id='run-b3bfd513-1873-419e-9217-fec799937b3c-0', usage_metadata={'input_tokens': 10297, 'output_tokens': 261, 'total_tokens': 10558, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('metadata_graph_node:73c298d1-b9ab-0398-ea8b-32eda584837d', 'entrez_agent_node:691315c3-a438-46da-b16c-30c6792d438e'), {'tools': {'messages': [ToolMessage(content="{'messages': [HumanMessage(content='- **Entrez ID**: 36185245\\n- **Study Information**:\\n  - **Title**: Differentiation of glioblastoma tissues using spontaneous Raman scattering with dimensionality reduction and data classification.\\n  - **Journal**: Frontiers in Oncology\\n  - **Publication Date**: October 4, 2022\\n  - **Authors**: Igor Romanishkin et al.\\n  \\n- **Sequencing Details**:\\n  - **Organism**: Homo sapiens\\n  - **Library Strategy**: RNA-Seq\\n  - **Library Source**: Transcriptomic Single Cell\\n  - **Library Selection**: cDNA\\n  - **Platform**: Illumina NovaSeq 6000\\n  - **Paired-End Sequencing**: Yes (indicated by the library layout)\\n  - **Single Cell RNA-seq**: Yes (indicated by the library source)\\n  - **10X Genomics Data**: Not specified, but the study involves single-cell RNA-seq which may utilize similar technologies.\\n\\n- **Additional Notes**:\\n  - The study focuses on the application of Raman spectroscopy for differentiating glioblastoma tissues, which is not directly related to sequencing but indicates a multi-faceted approach to understanding tumor biology.', additional_kwargs={}, response_metadata={}, name='efetch worker')]}", name='invoke_efetch_worker', id='15dcd940-ea27-4523-b0cb-039846d2ad1b', tool_call_id='call_Bck4DMVpkLuNOtfXT7lfoIl2')]}})
# (('metadata_graph_node:fca6da02-8804-2c8b-3c9c-833f0074e84f', 'entrez_agent_node:e4b980a8-9b12-a9b7-26cc-a455e1063b1e'), {'agent': {'messages': [AIMessage(content='- **Is the study Illumina sequence data?** Yes, it uses the Illumina NovaSeq 6000 platform.\n- **Is the study single cell RNA-seq data?** Yes, it is transcriptomic single cell data.\n- **Is the study paired-end sequencing data?** Yes, it is paired-end sequencing.\n- **Is the study 10X Genomics data?** Not specified as 10X Genomics data.\n- **Which organism was sequenced?** Homo sapiens (Human).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 108, 'prompt_tokens': 1339, 'total_tokens': 1447, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90354628f2', 'finish_reason': 'stop', 'logprobs': None}, id='run-37946deb-e0a1-4385-ac33-01666bbc47ea-0', usage_metadata={'input_tokens': 1339, 'output_tokens': 108, 'total_tokens': 1447, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('metadata_graph_node:fca6da02-8804-2c8b-3c9c-833f0074e84f',), {'entrez_agent_node': {'messages': [AIMessage(content='- **Is the study Illumina sequence data?** Yes, it uses the Illumina NovaSeq 6000 platform.\n- **Is the study single cell RNA-seq data?** Yes, it is transcriptomic single cell data.\n- **Is the study paired-end sequencing data?** Yes, it is paired-end sequencing.\n- **Is the study 10X Genomics data?** Not specified as 10X Genomics data.\n- **Which organism was sequenced?** Homo sapiens (Human).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 108, 'prompt_tokens': 1339, 'total_tokens': 1447, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90354628f2', 'finish_reason': 'stop', 'logprobs': None}, id='run-37946deb-e0a1-4385-ac33-01666bbc47ea-0', usage_metadata={'input_tokens': 1339, 'output_tokens': 108, 'total_tokens': 1447, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('metadata_graph_node:fca6da02-8804-2c8b-3c9c-833f0074e84f',), {'get_metadata_node': {'is_illumina': 'yes', 'is_single_cell': 'yes', 'is_paired_end': 'yes', 'is_10x': 'no', 'organism': 'human'}})
# (('metadata_graph_node:73c298d1-b9ab-0398-ea8b-32eda584837d', 'entrez_agent_node:691315c3-a438-46da-b16c-30c6792d438e'), {'agent': {'messages': [AIMessage(content='- **Is the study Illumina sequence data?** Yes, it uses the Illumina NovaSeq 6000 platform.\n- **Is the study single cell RNA-seq data?** Yes, it is single cell RNA-seq data.\n- **Is the study paired-end sequencing data?** Yes, it is paired-end sequencing data.\n- **Is the study 10X Genomics data?** Not specified, but it involves single-cell RNA-seq which may utilize similar technologies.\n- **Which organism was sequenced?** Homo sapiens.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 115, 'prompt_tokens': 1456, 'total_tokens': 1571, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90354628f2', 'finish_reason': 'stop', 'logprobs': None}, id='run-d4e6f8c1-3c88-4080-bb4a-9c98bd7b0dc0-0', usage_metadata={'input_tokens': 1456, 'output_tokens': 115, 'total_tokens': 1571, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('metadata_graph_node:73c298d1-b9ab-0398-ea8b-32eda584837d',), {'entrez_agent_node': {'messages': [AIMessage(content='- **Is the study Illumina sequence data?** Yes, it uses the Illumina NovaSeq 6000 platform.\n- **Is the study single cell RNA-seq data?** Yes, it is single cell RNA-seq data.\n- **Is the study paired-end sequencing data?** Yes, it is paired-end sequencing data.\n- **Is the study 10X Genomics data?** Not specified, but it involves single-cell RNA-seq which may utilize similar technologies.\n- **Which organism was sequenced?** Homo sapiens.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 115, 'prompt_tokens': 1456, 'total_tokens': 1571, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90354628f2', 'finish_reason': 'stop', 'logprobs': None}, id='run-d4e6f8c1-3c88-4080-bb4a-9c98bd7b0dc0-0', usage_metadata={'input_tokens': 1456, 'output_tokens': 115, 'total_tokens': 1571, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# (('metadata_graph_node:fca6da02-8804-2c8b-3c9c-833f0074e84f',), {'router_node': {'messages': [AIMessage(content='Enough of the metadata has been extracted.', additional_kwargs={}, response_metadata={})], 'route': 'Stop', 'rounds': 1}})
# (('metadata_graph_node:73c298d1-b9ab-0398-ea8b-32eda584837d',), {'get_metadata_node': {'is_illumina': 'yes', 'is_single_cell': 'yes', 'is_paired_end': 'yes', 'is_10x': 'unsure', 'organism': 'human'}})
# (('metadata_graph_node:73c298d1-b9ab-0398-ea8b-32eda584837d',), {'router_node': {'messages': [AIMessage(content='At least some of the metadata is still uncertain. Please try to provide more information by using a different approach.', additional_kwargs={}, response_metadata={})], 'route': 'Continue', 'rounds': 1}})
# (('metadata_graph_node:fca6da02-8804-2c8b-3c9c-833f0074e84f',), {'add2db_node': {'messages': [AIMessage(content='The results have been added to the database: SRAgent_database', additional_kwargs={}, response_metadata={})]}})
# ((), {'metadata_graph_node': {'is_illumina': ['yes'], 'is_single_cell': ['yes'], 'is_paired_end': ['yes'], 'is_10x': ['no'], 'organism': ['human']}})
# (('metadata_graph_node:73c298d1-b9ab-0398-ea8b-32eda584837d',), {'add2db_node': {'messages': [AIMessage(content='The results have been added to the database: SRAgent_database', additional_kwargs={}, response_metadata={})]}})
# ((), {'metadata_graph_node': {'is_illumina': ['yes'], 'is_single_cell': ['yes'], 'is_paired_end': ['yes'], 'is_10x': ['unsure'], 'organism': ['human']}})
# ((), {'final_state_node': {'database': 'gds', 'entrez_ids': ['36185246', '36185245'], 'SRX': [['SRX26777130'], ['SRX26777129']], 'SRP': [['SRP546381'], ['SRP546381']], 'SRR': [['SRR31408046', 'SRR31408047'], []], 'is_illumina': ['yes', 'yes'], 'is_single_cell': ['yes', 'yes'], 'is_paired_end': ['yes', 'yes'], 'is_10x': ['no', 'unsure'], 'organism': ['human', 'human']}})
# ---
# ((), {'final_state_node': {'database': 'gds', 'entrez_ids': ['36185246', '36185245'], 'SRX': [['SRX26777130'], ['SRX26777129']], 'SRP': [['SRP546381'], ['SRP546381']], 'SRR': [['SRR31408046', 'SRR31408047'], []], 'is_illumina': ['yes', 'yes'], 'is_single_cell': ['yes', 'yes'], 'is_paired_end': ['yes', 'yes'], 'is_10x': ['no', 'unsure'], 'organism': ['human', 'human']}})

# %% [markdown]
# ### Upload to gsheet

# %%
import gspread
from gspread_dataframe import set_with_dataframe

# %%
# # Authenticate and open the Google Sheet
# gc = gspread.service_account(filename=os.getenv("GOOGLE_APPLICATION_CREDENTIALS"))
# sheet = gc.open("SRAgent_database")
# worksheet = sheet.worksheet("database")

# %%
# # Read existing data to find where to append
# existing_data = pd.DataFrame(worksheet.get_all_values())
# existing_data

# %%
# next_row = len(existing_data) + 1
# # Append the data starting from the next row
# set_with_dataframe(worksheet, results, row=next_row, col=1, include_index=False, include_column_header=False)
