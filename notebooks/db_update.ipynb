# %% [markdown]
# # Goals
#
# * Check on the test and/or production databases

# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
import os
import pandas as pd
from pypika import Query, Table, Field, Column, Criterion

# %%
from SRAgent.db.connect import db_connect
from SRAgent.db.update import db_update
from SRAgent.db.utils import db_list_tables, db_glimpse_tables, db_get_table, execute_query

# %%
# set to production
os.environ['DYNACONF'] = 'prod'

# %% [markdown]
# # Summary

# %%
# list all of the tables in prod
with db_connect() as conn:
    print("\n".join(db_list_tables(conn)))
# Out:
# screcounter_star_results
# eval
# screcounter_trace
# srx_srr
# srx_metadata
# screcounter_log
# screcounter_star_params

# %% [markdown]
# # Database updates

# %% [markdown]
# ## CZI datasets

# %% [markdown]
# ### Organism

# %%
# read in srx-metadata as pandas dataframe
tbl = Table("srx_metadata")
stmt = Query \
    .from_(tbl) \
    .select(tbl.star) \
    .distinct() \
    .where(tbl.czi_collection_id.isnull().negate())

with db_connect() as conn:
    srx_metadata_cxg = pd.read_sql(str(stmt), conn)
srx_metadata_cxg
# Out:
#      database  entrez_id srx_accession is_illumina is_single_cell  \
# 0         sra    5980061    SRX4401543         yes             no
# 1         sra   19008386   SRX13671170         yes            yes
# 2         sra   21270522    ERX8792046         yes            yes
# 3         sra   33748102   ERX12098959         yes            yes
# 4         sra   30534579   SRX22540304         yes            yes
# ...       ...        ...           ...         ...            ...
# 6055      sra   30533995   SRX22539720         yes            yes
# 6056      sra   19008361   SRX13671145         yes             no
# 6057      sra    5987222    SRX4405260         yes            yes
# 6058      sra    9278658    SRX7059587         yes            yes
# 6059      sra   11941283    SRX9165759         yes            yes
#
#      is_paired_end      lib_prep        tech_10x       cell_prep organism  \
# 0               no         other  not_applicable  not_applicable    human
# 1              yes         other  not_applicable  single_nucleus    human
# 2               no  10x_Genomics     5_prime_gex     single_cell    human
# 3              yes  10x_Genomics     3_prime_gex     single_cell    human
# 4              yes  10x_Genomics     5_prime_gex     single_cell    human
# ...            ...           ...             ...             ...      ...
# 6055           yes  10x_Genomics     5_prime_gex     single_cell    human
# 6056           yes         other  not_applicable  single_nucleus    human
# 6057            no      MARS-seq  not_applicable     single_cell    human
# 6058           yes  10x_Genomics     3_prime_gex     single_cell    human
# 6059           yes  10x_Genomics           other     single_cell    human
#
#                                                  tissue  \
# 0                        Human prostate basal epithelia
# 1     Dorsolateral Prefrontal cortex (Brodmann area 46)
# 2                              Lung-draining lymph node
# 3                                    intercostal muscle
# 4            Peripheral Blood Mononuclear Cells (PBMCs)
# ...                                                 ...
# 6055                                              PBMCs
# 6056  Dorsolateral Prefrontal Cortex (Brodmann area 46)
# 6057                                        Bone Marrow
# 6058                                              brain
# 6059                              Fetal Small Intestine
#
#                        disease                      purturbation  \
# 0                       unsure                            unsure
# 1                       unsure                            unsure
# 2              Prostate cancer           Saquinavir-NO treatment
# 3     intracranial haemorrhage                            unsure
# 4                     COVID-19  COVID-19 mRNA vaccine (BNT162b2)
# ...                        ...                               ...
# 6055                  COVID-19              COVID-19 vaccination
# 6056       Alzheimer's Disease                            unsure
# 6057     Multiple myeloma (MM)                         Untreated
# 6058    glioblastoma, stage IV                            unsure
# 6059                    unsure                            unsure
#
#                                        cell_line  \
# 0                  D4PrF_BE, CD326+/CD271+/CD26-
# 1                                         unsure
# 2                                           PC-3
# 3     nuclei from human skeletal muscle biopsies
# 4                                          PBMCs
# ...                                          ...
# 6055                                       PBMCs
# 6056                                      unsure
# 6057                      Control donor (AB2835)
# 6058                                      unsure
# 6059                                      unsure
#
#                          czi_collection_id  \
# 0     e2a4a67f-6a18-431a-ab9c-6e77dd31cc80
# 1     91c8e321-566f-4f9d-b89e-3a164be654d5
# 2     62ef75e4-cbea-454e-a0ce-998ec40223d3
# 3     2d40e6a7-f2fd-49ba-9db9-6b97e4c6dad5
# 4     ecb739c5-fe0d-4b48-81c6-217c4d64eec4
# ...                                    ...
# 6055  ecb739c5-fe0d-4b48-81c6-217c4d64eec4
# 6056  91c8e321-566f-4f9d-b89e-3a164be654d5
# 6057  2a0b02c0-fea6-47bd-92b9-9b03f5d2580c
# 6058  999f2a15-3d7e-440b-96ae-2c806799c08c
# 6059  60358420-6055-411d-ba4f-e8ac80682a2e
#
#                                     czi_collection_name  \
# 0     A Cellular Anatomy of the Normal Adult Human P...
# 1     Neuron type-specific effects of human aging an...
# 2     Cross-tissue immune cell analysis reveals tiss...
# 3                    Human skeletal muscle ageing atlas
# 4     COVID-19 mRNA vaccine elicits a potent adaptiv...
# ...                                                 ...
# 6055  COVID-19 mRNA vaccine elicits a potent adaptiv...
# 6056  Neuron type-specific effects of human aging an...
# 6057  Single cell dissection of plasma cell heteroge...
# 6058  Harmonized single-cell landscape, intercellula...
# 6059  Spatiotemporal analysis of human intestinal de...
#
#                              notes                 created_at  \
# 0     Metadata obtained by SRAgent 2025-01-03 18:39:40.221883
# 1     Metadata obtained by SRAgent 2025-01-03 18:39:40.221883
# 2     Metadata obtained by SRAgent 2025-01-03 18:39:40.221883
# 3     Metadata obtained by SRAgent 2025-01-03 18:39:40.221883
# 4     Metadata obtained by SRAgent 2025-01-03 18:39:40.221883
# ...                            ...                        ...
# 6055  Metadata obtained by SRAgent 2025-01-03 18:39:40.221883
# 6056  Metadata obtained by SRAgent 2025-01-03 18:39:40.221883
# 6057  Metadata obtained by SRAgent 2025-01-03 18:39:40.221883
# 6058  Metadata obtained by SRAgent 2025-01-03 18:39:40.221883
# 6059  Metadata obtained by SRAgent 2025-01-03 18:39:40.221883
#
#                      updated_at
# 0    2025-02-18 01:17:18.338743
# 1    2025-02-18 01:48:15.592726
# 2    2025-02-16 03:08:04.360701
# 3    2025-02-15 15:20:42.842344
# 4    2025-02-15 23:28:22.014208
# ...                         ...
# 6055 2025-02-17 01:40:39.811736
# 6056 2025-02-17 03:59:44.582294
# 6057 2025-02-15 14:20:46.277606
# 6058 2025-02-15 03:37:30.793431
# 6059 2025-02-16 05:35:58.741302
#
# [6060 rows x 19 columns]

# %%
# summarize organism
srx_metadata_cxg.groupby("organism").size().sort_values(ascending=False)
# Out:
# organism
# human                5000
# mouse                1009
# Macaca mulatta         36
# Rattus norvegicus       5
# Sus scrofa              4
# Danio rerio             3
# Gallus gallus           2
# other                   1
# dtype: int64

# %%
# filter to just `other` organisms
srx_metadata_cxg[srx_metadata_cxg["organism"] == "other"][["srx_accession", "organism"]]
# Out:
#      srx_accession organism
# 3640   SRX13549222    other

# %%
# # update "other" organisms to correct
# idx = [
#     ['SRX9556667', 'human'], 
#     ['ERX12060278', 'human'], 
#     ['ERX12060274', 'human'], 
#     ['ERX12060276', 'human'], 
#     ['ERX12060273', 'human'], 
#     ['ERX12060297', 'human'], 
#     ['ERX12060299', 'human'], 
#     ['ERX12060275', 'human'], 
#     ['SRX13549222', 'other'],
#     ['SRX9556651', 'human'], 
#     ['ERX12060277', 'human'], 
# ]
# idx = pd.DataFrame(idx, columns=["srx_accession", "organism"])
# idx

# %%
# filter to just `other` organisms
srx_metadata_cxg[srx_metadata_cxg["organism"] == "NaN"][["srx_accession", "organism"]]
# Out:
# Empty DataFrame
# Columns: [srx_accession, organism]
# Index: []

# %%
# update "NaN" organisms to correct
# idx = [
# ['SRX22385964', 'human'],
# ['SRX22385973', 'human'],
# ['SRX22385959', 'human'],
# ['SRX22385965', 'human'],
# ['SRX18945635', 'mouse'],
# ['SRX22385974', 'human'],
# ['SRX22385969', 'human'],
# ['SRX18945636', 'mouse'],
# ['SRX22385976', 'human'],
# ['SRX22385960', 'human'],
# ['SRX18945634', 'mouse'],
# ['SRX22385962', 'human'],
# ['SRX22385972', 'human'],
# ]
# idx = pd.DataFrame(idx, columns=["srx_accession", "organism"])
# idx

# %%
# merge dataframes
srx_metadata_cxg_f = pd.merge(srx_metadata_cxg.drop(columns=["organism"]), idx, on="srx_accession", how="inner")
srx_metadata_cxg_f = srx_metadata_cxg_f[["database", "entrez_id", "srx_accession", "organism"]]
srx_metadata_cxg_f
# Out:
#    database  entrez_id srx_accession organism
# 0       sra   30368187   SRX22385964    human
# 1       sra   30368196   SRX22385973    human
# 2       sra   30368182   SRX22385959    human
# 3       sra   30368188   SRX22385965    human
# 4       sra   26077148   SRX18945635    mouse
# 5       sra   30368197   SRX22385974    human
# 6       sra   30368192   SRX22385969    human
# 7       sra   26077149   SRX18945636    mouse
# 8       sra   30368199   SRX22385976    human
# 9       sra   30368183   SRX22385960    human
# 10      sra   26077147   SRX18945634    mouse
# 11      sra   30368185   SRX22385962    human
# 12      sra   30368195   SRX22385972    human

# %%
with db_connect() as conn:
    db_update(srx_metadata_cxg_f, "srx_metadata", conn)

# %% [markdown]
# ### NaN

# %%
df = srx_metadata_cxg[srx_metadata_cxg["is_illumina"] == "NaN"][["entrez_id", "srx_accession"]]

# write to czi_annotate/nan.csv
df.to_csv("czi_annotate/nan.csv", index=False)

# %%
# !SRAgent metadata --no-summaries --use-database --no-srr czi_annotate/nan.csv

# %% [markdown]
# ### Tech 10x

# %%
# lib_prep != "10x_Genomics" & tech_10x != "not_applicable"
srx_metadata_cxg[(srx_metadata_cxg["lib_prep"] != "10x_Genomics") & (srx_metadata_cxg["tech_10x"] != "not_applicable")]
# Out:
#      database  entrez_id srx_accession is_illumina is_single_cell  \
# 1042      sra   19066359   SRX13707644         yes             no
# 1446      sra   29553044   ERX10811424         yes            yes
# 1648      sra   30368185   SRX22385962         NaN            NaN
# 1760      sra   30368192   SRX22385969         NaN            NaN
# 2171      sra   29561204   ERX10875792         yes            yes
# 2605      sra   30368195   SRX22385972         NaN            NaN
# 2841      sra   30368196   SRX22385973         NaN            NaN
# 2975      sra   31085102   ERX11760589         yes            yes
# 3014      sra   11539510    SRX8874821         yes            yes
# 3227      sra   30368187   SRX22385964         NaN            NaN
# 3283      sra   30368188   SRX22385965         NaN            NaN
# 4125      sra   30368183   SRX22385960         NaN            NaN
# 4280      sra   30368199   SRX22385976         NaN            NaN
# 4788      sra   30368182   SRX22385959         NaN            NaN
# 5571      sra   30368197   SRX22385974         NaN            NaN
#
#      is_paired_end    lib_prep     tech_10x       cell_prep organism  \
# 1042           yes       other        other  single_nucleus    human
# 1446            no       other     multiome  single_nucleus    human
# 1648           NaN         NaN          NaN             NaN    human
# 1760           NaN         NaN          NaN             NaN    human
# 2171            no       other        other     single_cell    human
# 2605           NaN         NaN          NaN             NaN    human
# 2841           NaN         NaN          NaN             NaN    human
# 2975            no       other        other     single_cell    human
# 3014           yes  Smart-seq2  3_prime_gex     single_cell    mouse
# 3227           NaN         NaN          NaN             NaN    human
# 3283           NaN         NaN          NaN             NaN    human
# 4125           NaN         NaN          NaN             NaN    human
# 4280           NaN         NaN          NaN             NaN    human
# 4788           NaN         NaN          NaN             NaN    human
# 5571           NaN         NaN          NaN             NaN    human
#
#                                                  tissue  \
# 1042  Dorsolateral Prefrontal Cortex (Brodmann area 46)
# 1446                                    sinoatrial node
# 1648                                                NaN
# 1760                                                NaN
# 2171                               heart left ventricle
# 2605                                                NaN
# 2841                                                NaN
# 2975                                               skin
# 3014                        Dorsal root ganglion neuron
# 3227                                                NaN
# 3283                                                NaN
# 4125                                                NaN
# 4280                                                NaN
# 4788                                                NaN
# 5571                                                NaN
#
#                     disease  \
# 1042                 unsure
# 1446                 normal
# 1648                    NaN
# 1760                    NaN
# 2171                 normal
# 2605                    NaN
# 2841                    NaN
# 2975  normal (healthy skin)
# 3014       neuropathic pain
# 3227                    NaN
# 3283                    NaN
# 4125                    NaN
# 4280                    NaN
# 4788                    NaN
# 5571                    NaN
#
#                                            purturbation       cell_line  \
# 1042                                             unsure          unsure
# 1446                                             unsure          unsure
# 1648                                                NaN             NaN
# 1760                                                NaN             NaN
# 2171                                               none            none
# 2605                                                NaN             NaN
# 2841                                                NaN             NaN
# 2975  bestatin (an inhibitor of leukotriene A4 hydro...       skin cell
# 3014                                            SNI 14d  not applicable
# 3227                                                NaN             NaN
# 3283                                                NaN             NaN
# 4125                                                NaN             NaN
# 4280                                                NaN             NaN
# 4788                                                NaN             NaN
# 5571                                                NaN             NaN
#
#                          czi_collection_id  \
# 1042  91c8e321-566f-4f9d-b89e-3a164be654d5
# 1446  3116d060-0a8e-4767-99bb-e866badea1ed
# 1648  0c8a364b-97b5-4cc8-a593-23c38c6f0ac5
# 1760  0c8a364b-97b5-4cc8-a593-23c38c6f0ac5
# 2171  3116d060-0a8e-4767-99bb-e866badea1ed
# 2605  0c8a364b-97b5-4cc8-a593-23c38c6f0ac5
# 2841  0c8a364b-97b5-4cc8-a593-23c38c6f0ac5
# 2975  34f12de7-c5e5-4813-a136-832677f98ac8
# 3014  03608e22-227a-4492-910b-3cb3f16f952e
# 3227  0c8a364b-97b5-4cc8-a593-23c38c6f0ac5
# 3283  0c8a364b-97b5-4cc8-a593-23c38c6f0ac5
# 4125  0c8a364b-97b5-4cc8-a593-23c38c6f0ac5
# 4280  0c8a364b-97b5-4cc8-a593-23c38c6f0ac5
# 4788  0c8a364b-97b5-4cc8-a593-23c38c6f0ac5
# 5571  0c8a364b-97b5-4cc8-a593-23c38c6f0ac5
#
#                                     czi_collection_name  \
# 1042  Neuron type-specific effects of human aging an...
# 1446  Spatially resolved multiomics of human cardiac...
# 1648  Single-cell and spatial transcriptomics charac...
# 1760  Single-cell and spatial transcriptomics charac...
# 2171  Spatially resolved multiomics of human cardiac...
# 2605  Single-cell and spatial transcriptomics charac...
# 2841  Single-cell and spatial transcriptomics charac...
# 2975  Multi-scale spatial mapping of cell population...
# 3014                                        iPain atlas
# 3227  Single-cell and spatial transcriptomics charac...
# 3283  Single-cell and spatial transcriptomics charac...
# 4125  Single-cell and spatial transcriptomics charac...
# 4280  Single-cell and spatial transcriptomics charac...
# 4788  Single-cell and spatial transcriptomics charac...
# 5571  Single-cell and spatial transcriptomics charac...
#
#                                          notes                 created_at  \
# 1042              Metadata obtained by SRAgent 2025-01-03 18:39:40.221883
# 1446              Metadata obtained by SRAgent 2025-01-03 18:39:40.221883
# 1648  New dataset found by Find-Datasets agent 2025-01-03 18:39:40.221883
# 1760  New dataset found by Find-Datasets agent 2025-01-03 18:39:40.221883
# 2171              Metadata obtained by SRAgent 2025-01-03 18:39:40.221883
# 2605  New dataset found by Find-Datasets agent 2025-01-03 18:39:40.221883
# 2841  New dataset found by Find-Datasets agent 2025-01-03 18:39:40.221883
# 2975              Metadata obtained by SRAgent 2025-01-03 18:39:40.221883
# 3014              Metadata obtained by SRAgent 2025-01-03 18:39:40.221883
# 3227  New dataset found by Find-Datasets agent 2025-01-03 18:39:40.221883
# 3283  New dataset found by Find-Datasets agent 2025-01-03 18:39:40.221883
# 4125  New dataset found by Find-Datasets agent 2025-01-03 18:39:40.221883
# 4280  New dataset found by Find-Datasets agent 2025-01-03 18:39:40.221883
# 4788  New dataset found by Find-Datasets agent 2025-01-03 18:39:40.221883
# 5571  New dataset found by Find-Datasets agent 2025-01-03 18:39:40.221883
#
#                      updated_at
# 1042 2025-02-15 02:12:50.913645
# 1446 2025-02-15 23:05:43.609785
# 1648 2025-02-19 04:03:50.873291
# 1760 2025-02-19 04:03:50.873291
# 2171 2025-02-17 09:33:18.347793
# 2605 2025-02-19 04:03:50.873291
# 2841 2025-02-19 04:03:50.873291
# 2975 2025-02-14 06:15:41.255389
# 3014 2025-02-15 18:34:42.489433
# 3227 2025-02-19 04:03:50.873291
# 3283 2025-02-19 04:03:50.873291
# 4125 2025-02-19 04:03:50.873291
# 4280 2025-02-19 04:03:50.873291
# 4788 2025-02-19 04:03:50.873291
# 5571 2025-02-19 04:03:50.873291

# %% [markdown]
# # sessionInfo

# %%
# !pip list
# Out:
# Package                       Version         Editable project location
# ----------------------------- --------------- --------------------------------------
# aiohappyeyeballs              2.4.3
# aiohttp                       3.10.10
# aiosignal                     1.3.1
# annotated-types               0.7.0
# anyio                         4.6.2.post1
# asttokens                     2.4.1
# attrs                         24.2.0
# beautifulsoup4                4.12.3
# biopython                     1.84
# cachetools                    5.5.0
# certifi                       2024.8.30
# charset-normalizer            3.4.0
# comm                          0.2.2
# dataclasses-json              0.6.7
# db-dtypes                     1.3.1
# debugpy                       1.8.7
# decorator                     5.1.1
# distro                        1.9.0
# dynaconf                      3.2.6
# exceptiongroup                1.2.2
# executing                     2.1.0
# frozenlist                    1.5.0
# google-api-core               2.23.0
# google-auth                   2.36.0
# google-auth-oauthlib          1.2.1
# google-cloud                  0.34.0
# google-cloud-bigquery         3.27.0
# google-cloud-bigquery-storage 2.27.0
# google-cloud-core             2.4.1
# google-cloud-secret-manager   2.22.0
# google-cloud-storage          2.19.0
# google-crc32c                 1.6.0
# google-resumable-media        2.7.2
# googleapis-common-protos      1.66.0
# greenlet                      3.1.1
# grpc-google-iam-v1            0.13.1
# grpcio                        1.68.1
# grpcio-status                 1.68.1
# gspread                       6.1.4
# gspread-dataframe             4.0.0
# h11                           0.14.0
# httpcore                      1.0.6
# httpx                         0.27.2
# httpx-sse                     0.4.0
# idna                          3.10
# importlib_metadata            8.5.0
# ipykernel                     6.29.5
# ipython                       8.29.0
# jedi                          0.19.1
# jiter                         0.7.0
# jsonpatch                     1.33
# jsonpointer                   3.0.0
# jupyter_client                8.6.3
# jupyter_core                  5.7.2
# langchain                     0.3.7
# langchain-community           0.3.5
# langchain-core                0.3.15
# langchain-openai              0.2.6
# langchain-text-splitters      0.3.2
# langchainhub                  0.1.21
# langgraph                     0.2.45
# langgraph-checkpoint          2.0.2
# langgraph-sdk                 0.1.35
# langsmith                     0.1.140
# marshmallow                   3.23.1
# matplotlib-inline             0.1.7
# msgpack                       1.1.0
# multidict                     6.1.0
# mypy-extensions               1.0.0
# nest_asyncio                  1.6.0
# numpy                         1.26.4
# oauthlib                      3.2.2
# openai                        1.57.2
# orjson                        3.10.11
# packaging                     24.1
# pandas                        2.2.3
# parso                         0.8.4
# pexpect                       4.9.0
# pickleshare                   0.7.5
# pip                           24.3.1
# platformdirs                  4.3.6
# prompt_toolkit                3.0.48
# propcache                     0.2.0
# proto-plus                    1.25.0
# protobuf                      5.29.1
# psutil                        6.1.0
# psycopg2-binary               2.9.10
# ptyprocess                    0.7.0
# pure_eval                     0.2.3
# pyarrow                       18.1.0
# pyasn1                        0.6.1
# pyasn1_modules                0.4.1
# pydantic                      2.9.2
# pydantic_core                 2.23.4
# pydantic-settings             2.6.1
# pyee                          12.0.0
# Pygments                      2.18.0
# PyPika                        0.48.9
# python-dateutil               2.9.0
# python-dotenv                 1.0.1
# pytz                          2024.2
# PyYAML                        6.0.2
# pyzmq                         26.2.0
# regex                         2024.11.6
# requests                      2.32.3
# requests-oauthlib             2.0.0
# requests-toolbelt             1.0.0
# rsa                           4.9
# setuptools                    75.3.0
# six                           1.16.0
# sniffio                       1.3.1
# soupsieve                     2.6
# SQLAlchemy                    2.0.35
# SRAgent                       0.1.0           /home/nickyoungblut/dev/python/SRAgent
# stack-data                    0.6.2
# tabulate                      0.9.0
# tenacity                      9.0.0
# tiktoken                      0.8.0
# tornado                       6.4.1
# tqdm                          4.67.0
# traitlets                     5.14.3
# types-requests                2.32.0.20241016
# typing_extensions             4.12.2
# typing-inspect                0.9.0
# tzdata                        2024.2
# urllib3                       2.2.3
# wcwidth                       0.2.13
# wheel                         0.44.0
# xmltodict                     0.14.2
# yarl                          1.17.1
# zipp                          3.20.2
