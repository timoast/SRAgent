# %% [markdown]
# # Goals
#
# * Migrate data from test to production

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
import pandas as pd

# %%
from SRAgent.db.connect import db_connect
from SRAgent.db.upsert import db_upsert
from SRAgent.db.utils import db_list_tables, db_glimpse_tables, db_get_table, execute_query
from SRAgent.db.get import db_find_srx
from SRAgent.db.create import create_table, create_table_router

# %%
# list all of the tables in test
os.environ['DYNACONF'] = 'test'
conn_test = db_connect() 
print("\n".join(db_list_tables(conn_test)))
# Out:
# srx_srr
# screcounter_star
# eval
# screcounter_log
# srx_metadata

# %%
db_glimpse_tables(conn_test)
# Out:
# #-- Table: srx_srr --#
# srx_accession	srr_accession	created_at	updated_at
# SRX26727599	SRR31350667	2024-12-18 17:37:23.074909	2024-12-18 17:37:23.074909
# SRX23538581	SRR27876733	2024-12-18 17:37:23.074909	2024-12-18 17:37:23.074909
# SRX23261451	SRR27592690	2024-12-18 17:37:23.074909	2024-12-18 17:37:23.074909
# SRX23261451	SRR27592688	2024-12-18 17:37:23.074909	2024-12-18 17:37:23.074909
# SRX23261451	SRR27592689	2024-12-18 17:37:23.074909	2024-12-18 17:37:23.074909
#
# #-- Table: screcounter_star --#
# sample	accession	feature	estimated_number_of_cells	fraction_of_unique_reads_in_cells	mean_gene_per_cell	mean_umi_per_cell	mean_feature_per_cell	median_gene_per_cell	median_umi_per_cell	median_feature_per_cell	number_of_reads	reads_with_valid_barcodes	sequencing_saturation	umis_in_cells	created_at	updated_at
# SRX19729045	SRR23917610	gene	139	1.0		4.0	3.0		1.0	1.0	100000	0	0.171386	556	2024-12-23 21:49:11.388231	2024-12-23 21:49:11.388231
# SRX19729045	SRR23917610	gene_ex50	197	1.0		3.0	3.0		1.0	1.0	100000	0	0.149675	784	2024-12-23 21:49:11.388231	2024-12-23 21:49:11.388231
# SRX19729045	SRR23917610	gene_ex_int	198	1.0		3.0	3.0		1.0	1.0	100000	0	0.1507	789	2024-12-23 21:49:11.388231	2024-12-23 21:49:11.388231
# SRX19729045	SRR23917610	gene_full	188	1.0		4.0	3.0		1.0	1.0	100000	0	0.147486	763	2024-12-23 21:49:11.388231	2024-12-23 21:49:11.388231
# SRX19729045	SRR23917610	velocyto	0								100000	0	-inf	0	2024-12-23 21:49:11.388231	2024-12-23 21:49:11.388231
#
# #-- Table: eval --#
# dataset_id	database	entrez_id	srx_accession	is_illumina	is_single_cell	is_paired_end	lib_prep	tech_10x	organism	cell_prep	created_at	updated_at
# eval1	sra	29115023	ERX11157721	yes	yes	yes	10x_Genomics	3_prime_gex	zebrafish	single_cell	2024-12-18 17:38:54.774086	2025-01-02 23:08:54.386892
# eval1	sra	36178506	ERX11887200	yes	yes	yes	10x_Genomics	3_prime_gex	mouse	single_cell	2024-12-18 17:38:54.774086	2025-01-02 23:08:54.386892
# eval1	sra	5920965	ERX2188110	yes	yes	yes	other	not_applicable	macaque	single_cell	2024-12-18 17:38:54.774086	2025-01-02 23:08:54.386892
# eval1	sra	34439895	ERX9692805	yes	yes	yes	10x_Genomics	3_prime_gex	chicken	single_cell	2024-12-18 17:38:54.774086	2025-01-02 23:08:54.386892
# eval1	gds	200271457	NaN	no	no	no	not_applicable	not_applicable	human	not_applicable	2024-12-18 17:38:54.774086	2025-01-02 23:08:54.386892
#
# #-- Table: screcounter_log --#
# sample	accession	process	step	status	message	created_at	updated_at
# ERX10987225	ERR11583756	get database accessions	Final	Success	Obtained database accession for processing	2024-12-23 03:56:14.065204	2024-12-23 03:56:14.065204
# ERX10987225	ERR11583807	get database accessions	Final	Success	Obtained database accession for processing	2024-12-23 03:56:14.065204	2024-12-23 03:56:14.065204
# ERX10987225	ERR11583914	get database accessions	Final	Success	Obtained database accession for processing	2024-12-23 03:56:14.065204	2024-12-23 03:56:14.065204
# ERX10987225	ERR11583981	get database accessions	Final	Success	Obtained database accession for processing	2024-12-23 03:56:14.065204	2024-12-23 03:56:14.065204
# ERX10987225	ERR11583986	get database accessions	Final	Success	Obtained database accession for processing	2024-12-23 03:56:14.065204	2024-12-23 03:56:14.065204
#
# #-- Table: srx_metadata --#
# database	entrez_id	srx_accession	is_illumina	is_single_cell	is_paired_end	lib_prep	tech_10x	cell_prep	organism	tissue	disease	purturbation	cell_line	notes	created_at	updated_at
# sra	33249542	SRX24914804	yes	yes	yes	Smart-seq2	not_applicable	single_cell	human	blood	Hepatitis C Virus (HCV) reinfection outcomes	Akebia Saponin D (ASD) and TNF-induced optic nerve damage	Memory B cells	Metadata obtained by SRAgent	2024-12-18 18:23:36.181001	2024-12-18 18:25:14.322667
# sra	34603139	SRX25602353	yes	yes	yes	10x_Genomics	other	single_cell	human	PBMCs	unsure	effects of salt intake in healthy humans	unsure	Metadata obtained by SRAgent	2024-12-18 18:23:36.181001	2024-12-18 18:25:33.937056
# sra	30864944													New dataset found by Find-Datasets agent	2025-01-03 17:29:09.649591	2025-01-03 17:29:09.649591
# sra	34602541													New dataset found by Find-Datasets agent	2025-01-03 17:29:09.649591	2025-01-03 17:29:09.649591
# sra	31225478	SRX23114342	yes	yes	yes	10x_Genomics	3_prime_gex	single_cell	mouse	sciatic nerve	spontaneous autoimmune neuropathy (CIDP)	unsure	immune cells (CD45+)	Metadata obtained by SRAgent	2024-12-18 18:40:50.574099	2024-12-18 18:42:11.558669

# %%
# list all of the tables in prod
os.environ['DYNACONF'] = 'prod'
conn_prod = db_connect() 
print("\n".join(db_list_tables(conn_prod)))
# Out:
# eval
# screcounter_log
# screcounter_star
# srx_srr
# srx_metadata

# %%
db_glimpse_tables(conn_prod)
# Out:
# #-- Table: eval --#
# dataset_id	database	entrez_id	srx_accession	is_illumina	is_single_cell	is_paired_end	lib_prep	tech_10x	organism	cell_prep	created_at	updated_at
#
# #-- Table: screcounter_log --#
# sample	accession	process	step	status	message	created_at	updated_at
#
# #-- Table: screcounter_star --#
# sample	accession	feature	estimated_number_of_cells	fraction_of_unique_reads_in_cells	mean_gene_per_cell	mean_umi_per_cell	mean_feature_per_cell	median_gene_per_cell	median_umi_per_cell	median_feature_per_cell	number_of_reads	reads_with_valid_barcodes	sequencing_saturation	umis_in_cells	created_at	updated_at
#
# #-- Table: srx_srr --#
# srx_accession	srr_accession	created_at	updated_at
#
# #-- Table: srx_metadata --#
# database	entrez_id	srx_accession	is_illumina	is_single_cell	is_paired_end	lib_prep	tech_10x	cell_prep	organism	tissue	disease	purturbation	cell_line	czi_collection_id	czi_collection_name	notes	created_at	updated_at

# %% [markdown]
# # SRX Metadata

# %% [markdown]
# ## Chris' processed records
#
# * Add to production database

# %%
infile = "../data/20241227_ChrisC_metadata_v1.tsv"
chris_cur_meta = pd.read_csv(infile, sep="\t").drop_duplicates()
chris_cur_meta
# Out:
#       database  entrez_id srx_accession  is_illumina  is_single_cell  \
# 0          sra   29110064   ERX11148781          NaN             NaN
# 1          sra   19007785   SRX13670569          NaN             NaN
# 2          sra   12488012    SRX9556597          NaN             NaN
# 14         sra   21270435    ERX8791959          NaN             NaN
# 15         sra   34493113   ERX12558784          NaN             NaN
# ...        ...        ...           ...          ...             ...
# 52899      sra   19008576   SRX13671360          NaN             NaN
# 52900      sra   21270500    ERX8792024          NaN             NaN
# 52901      sra   29110088   ERX11148805          NaN             NaN
# 52902      sra   10884261    ERX4126865          NaN             NaN
# 52903      sra   12773490    SRX9770752          NaN             NaN
#
#        is_paired_end        lib_prep tech_10x    cell_prep  organism  tissue  \
# 0                NaN  \t10x_Genomics       5'  single_cell       NaN     NaN
# 1                NaN             NaN      NaN          NaN       NaN     NaN
# 2                NaN  \t10x_Genomics       5'  single_cell       NaN     NaN
# 14               NaN  \t10x_Genomics       5'  single_cell       NaN     NaN
# 15               NaN  \t10x_Genomics       5'  single_cell       NaN     NaN
# ...              ...             ...      ...          ...       ...     ...
# 52899            NaN             NaN      NaN          NaN       NaN     NaN
# 52900            NaN  \t10x_Genomics       5'  single_cell       NaN     NaN
# 52901            NaN             NaN      NaN          NaN       NaN     NaN
# 52902            NaN             NaN      NaN          NaN       NaN     NaN
# 52903            NaN  \t10x_Genomics     3'v3  single_cell       NaN     NaN
#
#        disease  purturbation  cell_line                         notes  \
# 0          NaN           NaN        NaN  Processed by Chris Carpenter
# 1          NaN           NaN        NaN  Processed by Chris Carpenter
# 2          NaN           NaN        NaN  Processed by Chris Carpenter
# 14         NaN           NaN        NaN  Processed by Chris Carpenter
# 15         NaN           NaN        NaN  Processed by Chris Carpenter
# ...        ...           ...        ...                           ...
# 52899      NaN           NaN        NaN  Processed by Chris Carpenter
# 52900      NaN           NaN        NaN  Processed by Chris Carpenter
# 52901      NaN           NaN        NaN  Processed by Chris Carpenter
# 52902      NaN           NaN        NaN  Processed by Chris Carpenter
# 52903      NaN           NaN        NaN  Processed by Chris Carpenter
#
#       created_at updated_at   experiment  \
# 0        31:16.4    31:35.1  ERX11148781
# 1        31:16.4    31:35.1  SRX13670569
# 2        31:16.4    31:35.1   SRX9556597
# 14       31:16.4    31:35.1   ERX8791959
# 15       31:16.4    31:35.1  ERX12558784
# ...          ...        ...          ...
# 52899    31:16.4    31:35.1  SRX13671360
# 52900    31:16.4    31:35.1   ERX8792024
# 52901    31:16.4    31:35.1  ERX11148805
# 52902    31:16.4    31:35.1   ERX4126865
# 52903    31:16.4    31:35.1   SRX9770752
#
#                                      CZI_collection_name  \
# 0      Developmental cell programs are co-opted in in...
# 1      Neuron type-specific effects of human aging an...
# 2      Time-resolved Systems Immunology Reveals a Lat...
# 14     Cross-tissue immune cell analysis reveals tiss...
# 15     Early human lung immune cell development and i...
# ...                                                  ...
# 52899  Neuron type-specific effects of human aging an...
# 52900  Cross-tissue immune cell analysis reveals tiss...
# 52901  Developmental cell programs are co-opted in in...
# 52902  scRNA-seq assessment of the human lung, spleen...
# 52903  An Integrated Single Cell Atlas of Human Perio...
#
#                           CZI_collection_id
# 0      73f82ac8-15cc-4fcd-87f8-5683723fce7f
# 1      91c8e321-566f-4f9d-b89e-3a164be654d5
# 2      ed9185e3-5b82-40c7-9824-b2141590c7f0
# 14     62ef75e4-cbea-454e-a0ce-998ec40223d3
# 15     ec329aed-22bc-4d6e-8935-8282dcb1acac
# ...                                     ...
# 52899  91c8e321-566f-4f9d-b89e-3a164be654d5
# 52900  62ef75e4-cbea-454e-a0ce-998ec40223d3
# 52901  73f82ac8-15cc-4fcd-87f8-5683723fce7f
# 52902  4d74781b-8186-4c9a-b659-ff4dc4601d91
# 52903  71f4bccf-53d4-4c12-9e80-e73bfb89e398
#
# [6060 rows x 20 columns]

# %%
# remove the columns that are not in the database
chris_cur_meta.drop(["experiment", "created_at", "updated_at"], axis=1, inplace=True)

# %%
# lower case column names
chris_cur_meta.columns = chris_cur_meta.columns.str.lower()
chris_cur_meta
# Out:
#       database  entrez_id srx_accession  is_illumina  is_single_cell  \
# 0          sra   29110064   ERX11148781          NaN             NaN
# 1          sra   19007785   SRX13670569          NaN             NaN
# 2          sra   12488012    SRX9556597          NaN             NaN
# 14         sra   21270435    ERX8791959          NaN             NaN
# 15         sra   34493113   ERX12558784          NaN             NaN
# ...        ...        ...           ...          ...             ...
# 52899      sra   19008576   SRX13671360          NaN             NaN
# 52900      sra   21270500    ERX8792024          NaN             NaN
# 52901      sra   29110088   ERX11148805          NaN             NaN
# 52902      sra   10884261    ERX4126865          NaN             NaN
# 52903      sra   12773490    SRX9770752          NaN             NaN
#
#        is_paired_end        lib_prep tech_10x    cell_prep  organism  tissue  \
# 0                NaN  \t10x_Genomics       5'  single_cell       NaN     NaN
# 1                NaN             NaN      NaN          NaN       NaN     NaN
# 2                NaN  \t10x_Genomics       5'  single_cell       NaN     NaN
# 14               NaN  \t10x_Genomics       5'  single_cell       NaN     NaN
# 15               NaN  \t10x_Genomics       5'  single_cell       NaN     NaN
# ...              ...             ...      ...          ...       ...     ...
# 52899            NaN             NaN      NaN          NaN       NaN     NaN
# 52900            NaN  \t10x_Genomics       5'  single_cell       NaN     NaN
# 52901            NaN             NaN      NaN          NaN       NaN     NaN
# 52902            NaN             NaN      NaN          NaN       NaN     NaN
# 52903            NaN  \t10x_Genomics     3'v3  single_cell       NaN     NaN
#
#        disease  purturbation  cell_line                         notes  \
# 0          NaN           NaN        NaN  Processed by Chris Carpenter
# 1          NaN           NaN        NaN  Processed by Chris Carpenter
# 2          NaN           NaN        NaN  Processed by Chris Carpenter
# 14         NaN           NaN        NaN  Processed by Chris Carpenter
# 15         NaN           NaN        NaN  Processed by Chris Carpenter
# ...        ...           ...        ...                           ...
# 52899      NaN           NaN        NaN  Processed by Chris Carpenter
# 52900      NaN           NaN        NaN  Processed by Chris Carpenter
# 52901      NaN           NaN        NaN  Processed by Chris Carpenter
# 52902      NaN           NaN        NaN  Processed by Chris Carpenter
# 52903      NaN           NaN        NaN  Processed by Chris Carpenter
#
#                                      czi_collection_name  \
# 0      Developmental cell programs are co-opted in in...
# 1      Neuron type-specific effects of human aging an...
# 2      Time-resolved Systems Immunology Reveals a Lat...
# 14     Cross-tissue immune cell analysis reveals tiss...
# 15     Early human lung immune cell development and i...
# ...                                                  ...
# 52899  Neuron type-specific effects of human aging an...
# 52900  Cross-tissue immune cell analysis reveals tiss...
# 52901  Developmental cell programs are co-opted in in...
# 52902  scRNA-seq assessment of the human lung, spleen...
# 52903  An Integrated Single Cell Atlas of Human Perio...
#
#                           czi_collection_id
# 0      73f82ac8-15cc-4fcd-87f8-5683723fce7f
# 1      91c8e321-566f-4f9d-b89e-3a164be654d5
# 2      ed9185e3-5b82-40c7-9824-b2141590c7f0
# 14     62ef75e4-cbea-454e-a0ce-998ec40223d3
# 15     ec329aed-22bc-4d6e-8935-8282dcb1acac
# ...                                     ...
# 52899  91c8e321-566f-4f9d-b89e-3a164be654d5
# 52900  62ef75e4-cbea-454e-a0ce-998ec40223d3
# 52901  73f82ac8-15cc-4fcd-87f8-5683723fce7f
# 52902  4d74781b-8186-4c9a-b659-ff4dc4601d91
# 52903  71f4bccf-53d4-4c12-9e80-e73bfb89e398
#
# [6060 rows x 17 columns]

# %% [markdown]
# #### Format metadata

# %%
## count values in each character column
for col in ["is_illumina", "is_single_cell", "is_paired_end"]:
    print(chris_cur_meta[col].value_counts())
# Out:
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)

# %%
# format tech_10x
idx = {
    "5'": "5_prime_gex",
    "3'v3": "3_prime_gex",
    "3'v2": "3_prime_gex",
    "multiome GEX": "multiome",
}
for k,v in idx.items():
    chris_cur_meta["tech_10x"] = chris_cur_meta["tech_10x"].replace(k, v)

# %%
# format lib_prep
idx = {
    "\t10x_Genomics": "10x_Genomics",
}
for k,v in idx.items():
    chris_cur_meta["lib_prep"] = chris_cur_meta["lib_prep"].replace(k, v)

# %%
## count values in each character column
for col in ["lib_prep", "tech_10x", "cell_prep"]:
    print(chris_cur_meta[col].value_counts())
# Out:
# lib_prep
# 10x_Genomics    2223
# Name: count, dtype: int64
# tech_10x
# 3_prime_gex    1179
# 5_prime_gex     873
# multiome        122
# Name: count, dtype: int64
# cell_prep
# single_cell    2223
# Name: count, dtype: int64

# %%
## count values in each character column
for col in ["organism", "tissue", "disease", "purturbation", "cell_line"]:
    print(chris_cur_meta[col].value_counts())
# Out:
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)

# %%
# write to file
outfile = os.path.join("../data/", "20241227_ChrisC_metadata_v2.tsv")
chris_cur_meta.to_csv(outfile, sep="\t", index=False)

# %%
# %%bash
#
# ../scripts/db-tools.py --upsert-csv ../data/20241227_ChrisC_metadata_v2.tsv --upsert-target srx_metadata
# Out:
# Upserted ../data/20241227_ChrisC_metadata_v2.tsv into srx_metadata

# %%
# %%bash
#
# ../scripts/db-tools.py --glimpse
# Out:
# #-- Table: eval --#
# dataset_id	database	entrez_id	srx_accession	is_illumina	is_single_cell	is_paired_end	lib_prep	tech_10x	organism	cell_prep	created_at	updated_at
#
# #-- Table: screcounter_log --#
# sample	accession	process	step	status	message	created_at	updated_at
#
# #-- Table: screcounter_star --#
# sample	accession	feature	estimated_number_of_cells	fraction_of_unique_reads_in_cells	mean_gene_per_cell	mean_umi_per_cell	mean_feature_per_cell	median_gene_per_cell	median_umi_per_cell	median_feature_per_cell	number_of_reads	reads_with_valid_barcodes	sequencing_saturation	umis_in_cells	created_at	updated_at
#
# #-- Table: srx_srr --#
# srx_accession	srr_accession	created_at	updated_at
#
# #-- Table: srx_metadata --#
# database	entrez_id	srx_accession	is_illumina	is_single_cell	is_paired_end	lib_prep	tech_10x	cell_prep	organism	tissue	disease	purturbation	cell_line	czi_collection_id	czi_collection_name	notes	created_at	updated_at
# sra	29110064	ERX11148781	NaN	NaN	NaN	10x_Genomics	5_prime_gex	single_cell	NaN	NaN	NaN	NaN	NaN	73f82ac8-15cc-4fcd-87f8-5683723fce7f	Developmental cell programs are co-opted in inflammatory skin disease	Processed by Chris Carpenter	2025-01-03 18:39:40.221883	2025-01-03 18:39:40.221883
# sra	19007785	SRX13670569	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	91c8e321-566f-4f9d-b89e-3a164be654d5	Neuron type-specific effects of human aging and sex on DNA methylation and transcription	Processed by Chris Carpenter	2025-01-03 18:39:40.221883	2025-01-03 18:39:40.221883
# sra	12488012	SRX9556597	NaN	NaN	NaN	10x_Genomics	5_prime_gex	single_cell	NaN	NaN	NaN	NaN	NaN	ed9185e3-5b82-40c7-9824-b2141590c7f0	Time-resolved Systems Immunology Reveals a Late Juncture Linked to Fatal COVID-19	Processed by Chris Carpenter	2025-01-03 18:39:40.221883	2025-01-03 18:39:40.221883
# sra	21270435	ERX8791959	NaN	NaN	NaN	10x_Genomics	5_prime_gex	single_cell	NaN	NaN	NaN	NaN	NaN	62ef75e4-cbea-454e-a0ce-998ec40223d3	Cross-tissue immune cell analysis reveals tissue-specific features in humans	Processed by Chris Carpenter	2025-01-03 18:39:40.221883	2025-01-03 18:39:40.221883
# sra	34493113	ERX12558784	NaN	NaN	NaN	10x_Genomics	5_prime_gex	single_cell	NaN	NaN	NaN	NaN	NaN	ec329aed-22bc-4d6e-8935-8282dcb1acac	Early human lung immune cell development and its role in epithelial cell fate	Processed by Chris Carpenter	2025-01-03 18:39:40.221883	2025-01-03 18:39:40.221883

# %% [markdown]
# # Eval

# %%
eval_test = db_get_table( "eval", conn_test)
eval_test
# Out:
#    dataset_id database  entrez_id srx_accession is_illumina is_single_cell  \
# 0       eval1      sra   29115023   ERX11157721         yes            yes
# 1       eval1      sra   36178506   ERX11887200         yes            yes
# 2       eval1      sra    5920965    ERX2188110         yes            yes
# 3       eval1      sra   34439895    ERX9692805         yes            yes
# 4       eval1      gds  200271457           NaN          no             no
# 5       eval1      gds  200281884           NaN          no             no
# 6       eval1      sra   18060880   SRX13201194         yes             no
# 7       eval1      sra   30749595   SRX22716300         yes            yes
# 8       eval1      sra   31054998   SRX22985325         yes             no
# 9       eval1      sra   31679394   SRX23448232         yes             no
# 10      eval1      sra   32664033   SRX24349377         yes            yes
# 11      eval1      sra   33176418   SRX24842084         yes            yes
# 12      eval1      sra   35087715   SRX25994842         yes            yes
# 13      eval1      sra   35200088   SRX26085693         yes            yes
# 14      eval1      gds  200277303   SRX26099173         yes             no
# 15      eval1      sra   35536066   SRX26313156         yes             no
# 16      eval1      sra   35537624   SRX26314714          no            yes
# 17      eval1      sra   35979902   SRX26636208         yes             no
# 18      eval1      sra   36106630   SRX26727599         yes             no
# 19      eval1      sra   36209780   SRX26798077         yes             no
# 20      eval1      sra   36280358   SRX26854925         yes             no
# 21      eval2      sra   27454880   ERX10668381         yes            yes
# 22      eval2      sra   27454942   ERX10668443         yes            yes
# 23      eval2      sra   34046074   ERX10987225         yes            yes
# 24      eval2      sra   29108810   ERX11146221         yes            yes
# 25      eval2      sra   36096868   ERX11740068         yes            yes
# 26      eval2      sra   27238143   SRX19867681         yes            yes
# 27      eval2      sra   29740817   SRX21870188         yes            yes
# 28      eval2      sra   29914843   SRX22001630         yes            yes
# 29      eval2      sra   30464257   SRX22478468         yes            yes
# 30      eval2      sra   27694423   SRX20273490         yes            yes
# 31      eval2      sra   27694586   SRX20273653         yes            yes
# 32      eval2      sra   30774926   SRX22738634         yes            yes
# 33      eval2      sra   30775044   SRX22738752         yes            yes
# 34      eval2      sra   30864717   SRX22822772         yes            yes
# 35      eval2      sra   30865012   SRX22823067         yes            yes
# 36      eval2      sra   32927456   SRX24608694         yes            yes
# 37      eval2      sra   32927626   SRX24608864         yes            yes
# 38      eval2      sra   34602376  SRX25601590          yes            yes
# 39      eval2      sra   35200088   SRX26085693         yes            yes
#
#    is_paired_end        lib_prep        tech_10x    organism       cell_prep  \
# 0            yes    10x_Genomics     3_prime_gex   zebrafish     single_cell
# 1            yes    10x_Genomics     3_prime_gex       mouse     single_cell
# 2            yes           other  not_applicable     macaque     single_cell
# 3            yes    10x_Genomics     3_prime_gex     chicken     single_cell
# %%
srx_metadata_prod = db_get_table("srx_metadata", conn_prod)
srx_metadata_prod
# Out:
#      database  entrez_id srx_accession is_illumina is_single_cell  \
# 0         sra   29110064   ERX11148781         NaN            NaN
# 1         sra   19007785   SRX13670569         NaN            NaN
# 2         sra   12488012    SRX9556597         NaN            NaN
# 3         sra   21270435    ERX8791959         NaN            NaN
# 4         sra   34493113   ERX12558784         NaN            NaN
# ...       ...        ...           ...         ...            ...
# 6055      sra   19008576   SRX13671360         NaN            NaN
# 6056      sra   21270500    ERX8792024         NaN            NaN
# 6057      sra   29110088   ERX11148805         NaN            NaN
# 6058      sra   10884261    ERX4126865         NaN            NaN
# 6059      sra   12773490    SRX9770752         NaN            NaN
#
#      is_paired_end      lib_prep     tech_10x    cell_prep organism tissue  \
# 0              NaN  10x_Genomics  5_prime_gex  single_cell      NaN    NaN
# 1              NaN           NaN          NaN          NaN      NaN    NaN
# 2              NaN  10x_Genomics  5_prime_gex  single_cell      NaN    NaN
# 3              NaN  10x_Genomics  5_prime_gex  single_cell      NaN    NaN
# 4              NaN  10x_Genomics  5_prime_gex  single_cell      NaN    NaN
# ...            ...           ...          ...          ...      ...    ...
# 6055           NaN           NaN          NaN          NaN      NaN    NaN
# 6056           NaN  10x_Genomics  5_prime_gex  single_cell      NaN    NaN
# 6057           NaN           NaN          NaN          NaN      NaN    NaN
# 6058           NaN           NaN          NaN          NaN      NaN    NaN
# 6059           NaN  10x_Genomics  3_prime_gex  single_cell      NaN    NaN
#
#      disease purturbation cell_line                     czi_collection_id  \
# 0        NaN          NaN       NaN  73f82ac8-15cc-4fcd-87f8-5683723fce7f
# 1        NaN          NaN       NaN  91c8e321-566f-4f9d-b89e-3a164be654d5
# 2        NaN          NaN       NaN  ed9185e3-5b82-40c7-9824-b2141590c7f0
# 3        NaN          NaN       NaN  62ef75e4-cbea-454e-a0ce-998ec40223d3
# 4        NaN          NaN       NaN  ec329aed-22bc-4d6e-8935-8282dcb1acac
# ...      ...          ...       ...                                   ...
# 6055     NaN          NaN       NaN  91c8e321-566f-4f9d-b89e-3a164be654d5
# 6056     NaN          NaN       NaN  62ef75e4-cbea-454e-a0ce-998ec40223d3
# 6057     NaN          NaN       NaN  73f82ac8-15cc-4fcd-87f8-5683723fce7f
# 6058     NaN          NaN       NaN  4d74781b-8186-4c9a-b659-ff4dc4601d91
# 6059     NaN          NaN       NaN  71f4bccf-53d4-4c12-9e80-e73bfb89e398
#
#                                     czi_collection_name  \
# 0     Developmental cell programs are co-opted in in...
# 1     Neuron type-specific effects of human aging an...
# 2     Time-resolved Systems Immunology Reveals a Lat...
# 3     Cross-tissue immune cell analysis reveals tiss...
# 4     Early human lung immune cell development and i...
# ...                                                 ...
# 6055  Neuron type-specific effects of human aging an...
# 6056  Cross-tissue immune cell analysis reveals tiss...
# 6057  Developmental cell programs are co-opted in in...
# 6058  scRNA-seq assessment of the human lung, spleen...
# 6059  An Integrated Single Cell Atlas of Human Perio...
#
#                              notes                 created_at  \
# 0     Processed by Chris Carpenter 2025-01-03 18:39:40.221883
# 1     Processed by Chris Carpenter 2025-01-03 18:39:40.221883
# 2     Processed by Chris Carpenter 2025-01-03 18:39:40.221883
# 3     Processed by Chris Carpenter 2025-01-03 18:39:40.221883
# 4     Processed by Chris Carpenter 2025-01-03 18:39:40.221883
# ...                            ...                        ...
# 6055  Processed by Chris Carpenter 2025-01-03 18:39:40.221883
# 6056  Processed by Chris Carpenter 2025-01-03 18:39:40.221883
# 6057  Processed by Chris Carpenter 2025-01-03 18:39:40.221883
# 6058  Processed by Chris Carpenter 2025-01-03 18:39:40.221883
# 6059  Processed by Chris Carpenter 2025-01-03 18:39:40.221883
#
#                      updated_at
# 0    2025-01-03 18:39:40.221883
# 1    2025-01-03 18:39:40.221883
# 2    2025-01-03 18:39:40.221883
# 3    2025-01-03 18:39:40.221883
# 4    2025-01-03 18:39:40.221883
# ...                         ...
# 6055 2025-01-03 18:39:40.221883
# 6056 2025-01-03 18:39:40.221883
# 6057 2025-01-03 18:39:40.221883
# 6058 2025-01-03 18:39:40.221883
# 6059 2025-01-03 18:39:40.221883
#
# [6060 rows x 19 columns]

# %%
# filter out Chris' records
srx_metadata_prod_noChris = srx_metadata_prod[srx_metadata_prod["notes"] != "Processed by Chris Carpenter"]
srx_metadata_prod_noChris
# Out:
# Empty DataFrame
# Columns: [database, entrez_id, srx_accession, is_illumina, is_single_cell, is_paired_end, lib_prep, tech_10x, cell_prep, organism, tissue, disease, purturbation, cell_line, czi_collection_id, czi_collection_name, notes, created_at, updated_at]
# Index: []

# %% [markdown]
# # sessionInfo

# %%
# !conda list
# Out:
# # packages in environment at /home/nickyoungblut/miniforge3/envs/SRAgent:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# aiohappyeyeballs          2.4.4                    pypi_0    pypi
# aiohttp                   3.11.10                  pypi_0    pypi
# aiosignal                 1.3.2                    pypi_0    pypi
# annotated-types           0.7.0                    pypi_0    pypi
# anyio                     4.7.0                    pypi_0    pypi
# asttokens                 3.0.0              pyhd8ed1ab_1    conda-forge
# attrs                     24.2.0                   pypi_0    pypi
# beautifulsoup4            4.12.3                   pypi_0    pypi
# biopython                 1.84                     pypi_0    pypi
# build                     1.2.2.post1              pypi_0    pypi
# bzip2                     1.0.8                h4bc722e_7    conda-forge
# c-ares                    1.34.4               hb9d3cd8_0    conda-forge
# ca-certificates           2024.12.14           hbcca054_0    conda-forge
# cachetools                5.5.0                    pypi_0    pypi
# certifi                   2024.12.14               pypi_0    pypi
# charset-normalizer        3.4.0                    pypi_0    pypi
# comm                      0.2.2              pyhd8ed1ab_1    conda-forge
# curl                      8.11.1               h332b0f4_0    conda-forge
# dataclasses-json          0.6.7                    pypi_0    pypi
# db-dtypes                 1.3.1                    pypi_0    pypi
# debugpy                   1.8.11          py312h2ec8cdc_0    conda-forge
# decorator                 5.1.1              pyhd8ed1ab_1    conda-forge
# distro                    1.9.0                    pypi_0    pypi
# dynaconf                  3.2.6                    pypi_0    pypi
# exceptiongroup            1.2.2              pyhd8ed1ab_1    conda-forge
# executing                 2.1.0              pyhd8ed1ab_1    conda-forge
# frozenlist                1.5.0                    pypi_0    pypi
# google-api-core           2.24.0                   pypi_0    pypi
# google-auth               2.37.0                   pypi_0    pypi
# google-cloud-bigquery     3.27.0                   pypi_0    pypi
# google-cloud-bigquery-storage 2.27.0                   pypi_0    pypi
# google-cloud-core         2.4.1                    pypi_0    pypi
# google-cloud-secret-manager 2.22.0                   pypi_0    pypi
# google-crc32c             1.6.0                    pypi_0    pypi
# google-resumable-media    2.7.2                    pypi_0    pypi
# googleapis-common-protos  1.66.0                   pypi_0    pypi
# greenlet                  3.1.1                    pypi_0    pypi
# grpc-google-iam-v1        0.13.1                   pypi_0    pypi
# grpcio                    1.68.1                   pypi_0    pypi
# grpcio-status             1.68.1                   pypi_0    pypi
# h11                       0.14.0                   pypi_0    pypi
# httpcore                  1.0.7                    pypi_0    pypi
# httpx                     0.28.1                   pypi_0    pypi
# httpx-sse                 0.4.0                    pypi_0    pypi
# icu                       70.1                 h27087fc_0    conda-forge
# idna                      3.10                     pypi_0    pypi
# importlib-metadata        8.5.0              pyha770c72_1    conda-forge
# ipykernel                 6.29.5             pyh3099207_0    conda-forge
# ipython                   8.30.0             pyh707e725_0    conda-forge
# jedi                      0.19.2             pyhd8ed1ab_1    conda-forge
# jiter                     0.8.2                    pypi_0    pypi
# jsonpatch                 1.33                     pypi_0    pypi
# jsonpointer               3.0.0                    pypi_0    pypi
# jupyter_client            8.6.3              pyhd8ed1ab_1    conda-forge
# jupyter_core              5.7.2              pyh31011fe_1    conda-forge
# keyutils                  1.6.1                h166bdaf_0    conda-forge
# krb5                      1.21.3               h659f571_0    conda-forge
# langchain                 0.3.7                    pypi_0    pypi
# langchain-community       0.3.5                    pypi_0    pypi
# langchain-core            0.3.25                   pypi_0    pypi
# langchain-openai          0.2.6                    pypi_0    pypi
# langchain-text-splitters  0.3.3                    pypi_0    pypi
# langchainhub              0.1.21                   pypi_0    pypi
# langgraph                 0.2.45                   pypi_0    pypi
# langgraph-checkpoint      2.0.9                    pypi_0    pypi
# langgraph-sdk             0.1.45                   pypi_0    pypi
# langsmith                 0.1.147                  pypi_0    pypi
# ld_impl_linux-64          2.43                 h712a8e2_2    conda-forge
# libcurl                   8.11.1               h332b0f4_0    conda-forge
# libedit                   3.1.20191231         he28a2e2_2    conda-forge
# libev                     4.33                 hd590300_2    conda-forge
# libexpat                  2.6.4                h5888daf_0    conda-forge
# libffi                    3.4.2                h7f98852_5    conda-forge
# libgcc                    14.2.0               h77fa898_1    conda-forge
# libgcc-ng                 14.2.0               h69a702a_1    conda-forge
# libgomp                   14.2.0               h77fa898_1    conda-forge
# libiconv                  1.17                 hd590300_2    conda-forge
# liblzma                   5.6.3                hb9d3cd8_1    conda-forge
# liblzma-devel             5.6.3                hb9d3cd8_1    conda-forge
# libnghttp2                1.64.0               h161d5f1_0    conda-forge
# libnsl                    2.0.1                hd590300_0    conda-forge
# libsodium                 1.0.20               h4ab18f5_0    conda-forge
# libsqlite                 3.47.2               hee588c1_0    conda-forge
# libssh2                   1.11.1               hf672d98_0    conda-forge
# libstdcxx                 14.2.0               hc0a3c3a_1    conda-forge
# libstdcxx-ng              14.2.0               h4852527_1    conda-forge
# libuuid                   2.38.1               h0b41bf4_0    conda-forge
# libxcrypt                 4.4.36               hd590300_1    conda-forge
# libxml2                   2.9.14               h22db469_4    conda-forge
# libzlib                   1.3.1                hb9d3cd8_2    conda-forge
# marshmallow               3.23.1                   pypi_0    pypi
# matplotlib-inline         0.1.7              pyhd8ed1ab_1    conda-forge
# msgpack                   1.1.0                    pypi_0    pypi
# multidict                 6.1.0                    pypi_0    pypi
# mypy-extensions           1.0.0                    pypi_0    pypi
# ncbi-vdb                  3.1.1                h9948957_3    bioconda
# ncurses                   6.5                  he02047a_1    conda-forge
# nest-asyncio              1.6.0              pyhd8ed1ab_1    conda-forge
# numpy                     1.26.4                   pypi_0    pypi
# openai                    1.57.2                   pypi_0    pypi
# openssl                   3.4.0                hb9d3cd8_0    conda-forge
# orjson                    3.10.12                  pypi_0    pypi
# ossuuid                   1.6.2             hf484d3e_1000    conda-forge
# packaging                 24.2               pyhd8ed1ab_2    conda-forge
# pandas                    2.2.3                    pypi_0    pypi
# parso                     0.8.4              pyhd8ed1ab_1    conda-forge
# perl                      5.26.2            h36c2ea0_1008    conda-forge
# perl-app-cpanminus        1.7044                  pl526_1    bioconda
# perl-business-isbn        3.004                   pl526_0    bioconda
# perl-business-isbn-data   20140910.003            pl526_0    bioconda
# perl-carp                 1.38                    pl526_3    bioconda
# perl-constant             1.33                    pl526_1    bioconda
# perl-data-dumper          2.173                   pl526_0    bioconda
# perl-encode               2.88                    pl526_1    bioconda
# perl-exporter             5.72                    pl526_1    bioconda
# perl-extutils-makemaker   7.36                    pl526_1    bioconda
# perl-file-path            2.16                    pl526_0    bioconda
# perl-file-temp            0.2304                  pl526_2    bioconda
# perl-mime-base64          3.15                    pl526_1    bioconda
# perl-parent               0.236                   pl526_1    bioconda
# perl-uri                  1.76                    pl526_0    bioconda
# perl-xml-libxml           2.0132          pl526h7ec2d77_1    bioconda
# perl-xml-namespacesupport 1.12                    pl526_0    bioconda
# perl-xml-sax              1.02                    pl526_0    bioconda
# perl-xml-sax-base         1.09                    pl526_0    bioconda
# perl-xsloader             0.24                    pl526_0    bioconda
# pexpect                   4.9.0              pyhd8ed1ab_1    conda-forge
# pickleshare               0.7.5           pyhd8ed1ab_1004    conda-forge
# pip                       24.3.1             pyh8b19718_0    conda-forge
# platformdirs              4.3.6              pyhd8ed1ab_1    conda-forge
# prompt-toolkit            3.0.48             pyha770c72_1    conda-forge
# propcache                 0.2.1                    pypi_0    pypi
# proto-plus                1.25.0                   pypi_0    pypi
# protobuf                  5.29.1                   pypi_0    pypi
# psutil                    6.1.0           py312h66e93f0_0    conda-forge
# psycopg2-binary           2.9.10                   pypi_0    pypi
# ptyprocess                0.7.0              pyhd8ed1ab_1    conda-forge
# pure_eval                 0.2.3              pyhd8ed1ab_1    conda-forge
# pyarrow                   18.1.0                   pypi_0    pypi
# pyasn1                    0.6.1                    pypi_0    pypi
# pyasn1-modules            0.4.1                    pypi_0    pypi
# pydantic                  2.10.3                   pypi_0    pypi
# pydantic-core             2.27.1                   pypi_0    pypi
# pydantic-settings         2.7.0                    pypi_0    pypi
# pygments                  2.18.0             pyhd8ed1ab_1    conda-forge
# pypika                    0.48.9                   pypi_0    pypi
# pyproject-hooks           1.2.0                    pypi_0    pypi
# python                    3.12.8          h9e4cc4f_1_cpython    conda-forge
# python-dateutil           2.9.0.post0        pyhff2d567_1    conda-forge
# python-dotenv             1.0.1                    pypi_0    pypi
# python_abi                3.12                    5_cp312    conda-forge
# pytz                      2024.2                   pypi_0    pypi
# pyyaml                    6.0.2                    pypi_0    pypi
# pyzmq                     26.2.0          py312hbf22597_3    conda-forge
# readline                  8.2                  h8228510_1    conda-forge
# regex                     2024.11.6                pypi_0    pypi
# requests                  2.32.3                   pypi_0    pypi
# requests-toolbelt         1.0.0                    pypi_0    pypi
# rsa                       4.9                      pypi_0    pypi
# setuptools                75.6.0             pyhff2d567_1    conda-forge
# six                       1.17.0             pyhd8ed1ab_0    conda-forge
# sniffio                   1.3.1                    pypi_0    pypi
# soupsieve                 2.6                      pypi_0    pypi
# sqlalchemy                2.0.35                   pypi_0    pypi
# sra-tools                 3.1.1                h4304569_2    bioconda
# sragent                   0.1.0                    pypi_0    pypi
# stack_data                0.6.3              pyhd8ed1ab_1    conda-forge
# tabulate                  0.9.0                    pypi_0    pypi
# tenacity                  9.0.0                    pypi_0    pypi
# tiktoken                  0.8.0                    pypi_0    pypi
# tk                        8.6.13          noxft_h4845f30_101    conda-forge
# tornado                   6.4.2           py312h66e93f0_0    conda-forge
# tqdm                      4.67.1                   pypi_0    pypi
# traitlets                 5.14.3             pyhd8ed1ab_1    conda-forge
# types-requests            2.32.0.20241016          pypi_0    pypi
# typing-inspect            0.9.0                    pypi_0    pypi
# typing_extensions         4.12.2             pyha770c72_1    conda-forge
# tzdata                    2024.2                   pypi_0    pypi
# urllib3                   2.2.3                    pypi_0    pypi
# wcwidth                   0.2.13             pyhd8ed1ab_1    conda-forge
# wheel                     0.45.1             pyhd8ed1ab_1    conda-forge
# xmltodict                 0.14.2                   pypi_0    pypi
# xz                        5.6.3                hbcc6ac9_1    conda-forge
# xz-gpl-tools              5.6.3                hbcc6ac9_1    conda-forge
# xz-tools                  5.6.3                hb9d3cd8_1    conda-forge
# yarl                      1.18.3                   pypi_0    pypi
# zeromq                    4.3.5                h3b0a872_7    conda-forge
# zipp                      3.21.0             pyhd8ed1ab_1    conda-forge
# zstd                      1.5.6                ha6fb4c9_0    conda-forge
