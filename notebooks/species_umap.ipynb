# %% [markdown]
# # Goal
#
# * Create a list of processed SRX accessions per species, with file paths
# * These will be used to create UMAP plots for certain species

# %% [markdown]
# # Init

# %%
import os
from glob import glob
from dotenv import load_dotenv
import pandas as pd
from pypika import Query, Table, Criterion, functions as fn
from SRAgent.db.connect import db_connect

# %%
load_dotenv(override=True)
os.environ["DYNACONF"] = "prod"

# %% [markdown]
# # Load data

# %%
# read in star results
tbl = Table("screcounter_star_results")
stmt = Query \
    .from_(tbl) \
    .select("*") \
    .where(tbl.feature == "gene_ex50") \
    .where(tbl.estimated_number_of_cells > 3000)

with db_connect() as conn:
    star_results = pd.read_sql(str(stmt), conn)
star_results
# Out:
#             sample    feature  estimated_number_of_cells  \
# 0      ERX10396585  gene_ex50                       4875
# 1      ERX10855741  gene_ex50                       4299
# 2       ERX9427783  gene_ex50                       6404
# 3      ERX10855742  gene_ex50                       3428
# 4      ERX10981676  gene_ex50                       7703
# ...            ...        ...                        ...
# 22439  SRX25708138  gene_ex50                      10802
# 22440  SRX22169670  gene_ex50                       8198
# 22441  SRX25713883  gene_ex50                      12881
# 22442  SRX25708136  gene_ex50                      11669
# 22443  SRX23028808  gene_ex50                       4082
#
#        fraction_of_unique_reads_in_cells mean_gene_per_cell  \
# 0                               0.869061               None
# 1                               0.876242               None
# 2                               0.889150               None
# 3                               0.888622               None
# 4                               0.890946               None
# ...                                  ...                ...
# 22439                           0.936122               None
# 22440                           0.711641               None
# 22441                           0.904704               None
# 22442                           0.890490               None
# 22443                           0.647429               None
#
#        mean_umi_per_cell  mean_feature_per_cell median_gene_per_cell  \
# 0                33160.0                 5162.0                 None
# 1                 5126.0                 2524.0                 None
# 2                 8624.0                 2714.0                 None
# 3                 5346.0                 2551.0                 None
# 4                 6834.0                 2250.0                 None
# ...                  ...                    ...                  ...
# 22439             8037.0                 2342.0                 None
# 22440             1860.0                  953.0                 None
# 22441            20517.0                 3982.0                 None
# 22442            10461.0                 2872.0                 None
# 22443            17121.0                 3342.0                 None
#
#        median_umi_per_cell  median_feature_per_cell  ...  \
# 0                  33087.0                   6150.0  ...
# 1                   4492.0                   2416.0  ...
# 2                   7230.0                   2694.0  ...
# 3                   4247.0                   2329.0  ...
# 4                   5547.0                   2094.0  ...
# ...                    ...                      ...  ...
# 22439               5020.0                   1971.0  ...
# 22440               1425.0                    862.0  ...
# 22441              10257.0                   3793.0  ...
# 22442               6899.0                   2536.0  ...
# 22443               9408.0                   3136.0  ...
#
#        reads_with_valid_barcodes  sequencing_saturation  \
# 0                       0.977392               0.219096
# 1                       0.961318               0.723613
# 2                       0.975229               0.484923
# 3                       0.959722               0.725166
# 4                       0.975521               0.605853
# ...                          ...                    ...
# 22439                   0.921812               0.393687
# 22440                   0.967051               0.277983
# 22441                   0.947238               0.421060
# 22442                   0.917599               0.599476
# 22443                   0.955628               0.523959
#
#        total_feature_detected  umis_in_cells  \
# 0                     25479.0      161657597
# 1                     28667.0       22039225
# 2                     29386.0       55230288
# 3                     28140.0       18326986
# 4                     23180.0       52648371
# ...                       ...            ...
# 22439                 20388.0       86820516
# 22440                 10472.0       15256050
# 22441                 28701.0      264287183
# 22442                 21799.0      122069877
# 22443                 23328.0       69888225
#
#        unique_reads_in_cells_mapped_to_gene  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 22439                                   NaN
# 22440                                   NaN
# 22441                                   NaN
# 22442                                   NaN
# 22443                                   NaN
#
#        unique_reads_in_cells_mapped_to_genefull  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 22439                                       NaN
# 22440                                       NaN
# 22441                                       NaN
# 22442                                       NaN
# 22443                                       NaN
#
#        unique_reads_in_cells_mapped_to_genefull_ex50pas  \
# 0                                           207340012.0
# 1                                            81002428.0
# 2                                           107808456.0
# 3                                            68051908.0
# 4                                           136342362.0
# ...                                                 ...
# 22439                                       143097465.0
# 22440                                        21361026.0
# 22441                                       461781442.0
# 22442                                       304941897.0
# 22443                                       149384382.0
#
#        unique_reads_in_cells_mapped_to_genefull_exonoverintron  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 22439                                                NaN
# 22440                                                NaN
# 22441                                                NaN
# 22442                                                NaN
# 22443                                                NaN
#
#                       created_at                 updated_at
# 0     2025-01-13 16:03:19.007361 2025-01-14 20:06:25.557352
# 1     2025-01-13 16:56:43.936232 2025-01-14 20:06:25.557352
# 2     2025-01-14 21:19:47.161614 2025-01-14 21:19:47.161614
# 3     2025-01-13 16:50:48.249748 2025-01-14 20:06:25.557352
# 4     2025-01-13 17:08:48.729106 2025-01-14 20:06:25.557352
# ...                          ...                        ...
# 22439 2025-02-20 22:57:54.885096 2025-02-20 22:57:54.885096
# 22440 2025-02-20 23:18:06.387448 2025-02-20 23:18:06.387448
# 22441 2025-02-20 23:40:10.887207 2025-02-20 23:40:10.887207
# 22442 2025-02-20 23:41:32.051897 2025-02-20 23:41:32.051897
# 22443 2025-02-20 23:53:51.322869 2025-02-20 23:53:51.322869
#
# [22444 rows x 36 columns]

# %%
# read in srx-metadata as pandas dataframe
tbl = Table("srx_metadata")
stmt = Query \
    .from_(tbl) \
    .select("*") \
    .distinct() \
    .where(tbl.czi_collection_id.isnull())

with db_connect() as conn:
    srx_metadata = pd.read_sql(str(stmt), conn)
srx_metadata
# Out:
#       database  entrez_id srx_accession is_illumina is_single_cell  \
# 0          sra     100000     SRX087804         yes             no
# 1          sra     100001     SRX087805         yes             no
# 2          sra     100002     SRX087806         yes             no
# 3          sra     100003     SRX087807         yes             no
# 4          sra     100004     SRX087808         yes             no
# ...        ...        ...           ...         ...            ...
# 67598      sra  100000005          None        None           None
# 67599      sra  100000006          None        None           None
# 67600      sra  100000007          None        None           None
# 67601      sra  100000008          None        None           None
# 67602      sra  100000009   SRX11094056         yes             no
#
#       is_paired_end        lib_prep        tech_10x       cell_prep organism  \
# 0               yes  not_applicable  not_applicable  not_applicable    other
# 1               yes  not_applicable  not_applicable  not_applicable    other
# 2               yes  not_applicable  not_applicable  not_applicable    other
# 3               yes  not_applicable  not_applicable  not_applicable    other
# 4               yes  not_applicable  not_applicable  not_applicable    other
# ...             ...             ...             ...             ...      ...
# 67598          None            None            None            None     None
# 67599          None            None            None            None     None
# 67600          None            None            None            None     None
# 67601          None            None            None            None     None
# 67602           yes  not_applicable  not_applicable  not_applicable    other
#
#               tissue        disease  \
# 0      not specified  not specified
# 1             unsure         unsure
# 2             unsure         unsure
# 3             unsure         unsure
# 4             unsure         unsure
# ...              ...            ...
# 67598           None           None
# 67599           None           None
# 67600           None           None
# 67601           None           None
# 67602       mycelium         unsure
#
#                                             purturbation  \
# 0                                          not specified
# 1                                                 unsure
# 2                                                 unsure
# 3                                                 unsure
# 4                                                 unsure
# ...                                                  ...
# 67598                                               None
# 67599                                               None
# 67600                                               None
# 67601                                               None
# 67602  incubation substrates: xylan; sampling time: 4...
#
#                   cell_line czi_collection_id czi_collection_name  \
# 0             not specified              None                None
# 1            not_applicable              None                None
# 2                    unsure              None                None
# 3                    unsure              None                None
# 4                    unsure              None                None
# ...                     ...               ...                 ...
# 67598                  None              None                None
# 67599                  None              None                None
# 67600                  None              None                None
# 67601                  None              None                None
# 67602  strain: delta_Tgace2              None                None
#
#                                           notes                 created_at  \
# 0                  Metadata obtained by SRAgent 2025-02-11 11:20:27.383612
# 1                  Metadata obtained by SRAgent 2025-02-11 11:20:27.383612
# 2                  Metadata obtained by SRAgent 2025-02-11 11:20:27.383612
# 3                  Metadata obtained by SRAgent 2025-02-11 11:20:27.383612
# 4                  Metadata obtained by SRAgent 2025-02-11 11:20:27.383612
# ...                                         ...                        ...
# 67598  New dataset found by Find-Datasets agent 2025-01-16 13:20:31.752503
# 67599  New dataset found by Find-Datasets agent 2025-01-16 13:20:31.752503
# 67600  New dataset found by Find-Datasets agent 2025-01-16 13:20:31.752503
# 67601  New dataset found by Find-Datasets agent 2025-01-16 13:20:31.752503
# 67602              Metadata obtained by SRAgent 2025-01-16 13:20:31.752503
#
#                       updated_at
# 0     2025-02-11 11:22:05.479718
# 1     2025-02-11 11:21:54.748818
# 2     2025-02-11 11:22:00.892413
# 3     2025-02-11 11:21:55.084329
# 4     2025-02-11 11:21:53.522703
# ...                          ...
# 67598 2025-01-16 13:20:31.752503
# 67599 2025-01-16 13:20:31.752503
# 67600 2025-01-16 13:20:31.752503
# 67601 2025-01-16 13:20:31.752503
# 67602 2025-01-16 13:26:41.517420
#
# [67603 rows x 19 columns]

# %%
# filter to star results
srx_metadata = srx_metadata[srx_metadata["srx_accession"].isin(star_results["sample"])]
srx_metadata.shape
# Out:
# (22422, 19)

# %%
# get 100 of each organism
srx_metadata = srx_metadata.groupby("organism").head(100).reset_index(drop=True)
srx_metadata
# Out:
#      database  entrez_id srx_accession is_illumina is_single_cell  \
# 0         sra   10094477    SRX7723647         yes            yes
# 1         sra   10524643    SRX8082006         yes            yes
# 2         sra   10525137    SRX8082500         yes            yes
# 3         sra   10969899    SRX8434172         yes            yes
# 4         sra   11032409    SRX8487983         yes            yes
# ...       ...        ...           ...         ...            ...
# 1099      sra   36084756   SRX26708354         yes            yes
# 1100      sra   36084758   SRX26708356         yes            yes
# 1101      sra   36879056   SRX27335701         yes            yes
# 1102      sra   37124417   SRX27536440         yes            yes
# 1103      sra   37124423   SRX27536446         yes            yes
#
#      is_paired_end      lib_prep     tech_10x    cell_prep  \
# 0              yes  10x_Genomics  3_prime_gex  single_cell
# 1              yes  10x_Genomics  3_prime_gex  single_cell
# 2              yes  10x_Genomics  3_prime_gex  single_cell
# 3              yes  10x_Genomics  3_prime_gex  single_cell
# 4              yes  10x_Genomics  3_prime_gex  single_cell
# ...            ...           ...          ...          ...
# 1099           yes  10x_Genomics  3_prime_gex  single_cell
# 1100           yes  10x_Genomics  3_prime_gex  single_cell
# 1101           yes  10x_Genomics  3_prime_gex  single_cell
# 1102           yes  10x_Genomics  3_prime_gex  single_cell
# 1103           yes  10x_Genomics  3_prime_gex  single_cell
#
#                      organism                                         tissue  \
# 0     Drosophila melanogaster                       ureter and lower tubules
# 1                 Danio rerio                                 whole organism
# 2                 Danio rerio                                 whole organism
# 3                 Danio rerio                                     caudal fin
# 4                    Zea mays  SAM (Shoot Apical Meristem), plastochrons 1-6
# ...                       ...                                            ...
# 1099            Gallus gallus                                         Somite
# 1100            Gallus gallus                                         somite
# 1101   Caenorhabditis elegans                         rab-3::tagRFP+ neurons
# 1102     Solanum lycopersicum                              Adventitious root
# 1103     Solanum lycopersicum                              Adventitious root
#
#                disease                                       purturbation  \
# 0        not specified                                      not specified
# 1        not specified                                      not specified
# 2        not specified  micro-injected with gRNA pool and Cas9 mRNA mi...
# 3     Strongyloidiasis  Ivermectin, Thiabendazole, Mebendazole, Albend...
# 4                 none                                               none
# ...                ...                                                ...
# 1099            unsure                                             unsure
# 1100     not specified                                      not specified
# 1101              none                                  young adult males
# 1102            unsure                                 Hydroponic culture
# 1103            unsure                                 Hydroponic culture
#
#                        cell_line czi_collection_id czi_collection_name  \
# 0                 not applicable              None                None
# 1                 not applicable              None                None
# 2                 not applicable              None                None
# 3                         unsure              None                None
# 4     single cells (protoplasts)              None                None
# ...                          ...               ...                 ...
# 1099                      unsure              None                None
# 1100               not specified              None                None
# 1101                      MOS264              None                None
# 1102                      unsure              None                None
# 1103              not applicable              None                None
#
#                              notes                 created_at  \
# 0     Metadata obtained by SRAgent 2025-02-10 13:20:27.590900
# 1     Metadata obtained by SRAgent 2025-02-10 14:05:29.747741
# 2     Metadata obtained by SRAgent 2025-02-08 05:25:29.492257
# 3     Metadata obtained by SRAgent 2025-02-09 18:20:32.244925
# 4     Metadata obtained by SRAgent 2025-02-10 18:25:31.352826
# ...                            ...                        ...
# 1099  Metadata obtained by SRAgent 2025-02-08 16:15:27.270171
# 1100  Metadata obtained by SRAgent 2025-02-10 04:45:31.519252
# 1101  Metadata obtained by SRAgent 2025-02-09 15:55:28.997356
# 1102  Metadata obtained by SRAgent 2025-02-16 10:30:26.807923
# 1103  Metadata obtained by SRAgent 2025-02-16 10:30:26.807923
#
#                      updated_at
# 0    2025-02-10 13:23:31.772165
# 1    2025-02-10 14:09:52.175351
# 2    2025-02-08 05:26:38.375022
# 3    2025-02-09 18:21:47.191491
# 4    2025-02-10 18:29:03.676546
# ...                         ...
# 1099 2025-02-08 16:18:16.793937
# 1100 2025-02-10 04:46:54.953339
# 1101 2025-02-09 15:57:05.945129
# 1102 2025-02-16 10:31:36.464400
# 1103 2025-02-16 10:31:38.107846
#
# [1104 rows x 19 columns]

# %%
# 
srx_metadata["organism"].value_counts()
# Out:
# organism
# Drosophila melanogaster    100
# Danio rerio                100
# Mus musculus               100
# Macaca mulatta             100
# Homo sapiens               100
# Sus scrofa                 100
# Arabidopsis thaliana       100
# Gallus gallus               72
# Heterocephalus glaber       68
# Bos taurus                  42
# Caenorhabditis elegans      35
# Pan troglodytes             34
# Zea mays                    31
# Oryctolagus cuniculus       29
# Oryza sativa                27
# Callithrix jacchus          21
# Ovis aries                  20
# Equus caballus              11
# Solanum lycopersicum         9
# Schistosoma mansoni          3
# Gorilla gorilla              2
# Name: count, dtype: int64

# %%
# get all SRX directories
to_keep = set(srx_metadata["srx_accession"].tolist())
files = []
for x in glob("/processed_datasets/scRecount/scRecounter/prod3/*/STAR/*"):
    if os.path.basename(x) in to_keep:
        files.append([os.path.basename(x), x])
        
# convert to dataframe
files_df = pd.DataFrame(files, columns=["srx_accession", "path"])
files_df
# Out:
#      srx_accession                                               path
# 0      SRX19907345  /processed_datasets/scRecount/scRecounter/prod...
# 1      SRX19907347  /processed_datasets/scRecount/scRecounter/prod...
# 2      SRX19907342  /processed_datasets/scRecount/scRecounter/prod...
# 3      SRX22821312  /processed_datasets/scRecount/scRecounter/prod...
# 4      SRX19498729  /processed_datasets/scRecount/scRecounter/prod...
# ...            ...                                                ...
# 1085    SRX9689819  /processed_datasets/scRecount/scRecounter/prod...
# 1086    SRX9689818  /processed_datasets/scRecount/scRecounter/prod...
# 1087   ERX10138352  /processed_datasets/scRecount/scRecounter/prod...
# 1088   ERX10138355  /processed_datasets/scRecount/scRecounter/prod...
# 1089   ERX10138354  /processed_datasets/scRecount/scRecounter/prod...
#
# [1090 rows x 2 columns]

# %%
# merge with metadata
srx_metadata = srx_metadata.merge(files_df, on="srx_accession", how="inner")
srx_metadata
# Out:
#      database  entrez_id srx_accession is_illumina is_single_cell  \
# 0         sra   10094477    SRX7723647         yes            yes
# 1         sra   10524643    SRX8082006         yes            yes
# 2         sra   10525137    SRX8082500         yes            yes
# 3         sra   10969899    SRX8434172         yes            yes
# 4         sra   11032409    SRX8487983         yes            yes
# ...       ...        ...           ...         ...            ...
# 1085      sra   36084756   SRX26708354         yes            yes
# 1086      sra   36084758   SRX26708356         yes            yes
# 1087      sra   36879056   SRX27335701         yes            yes
# 1088      sra   37124417   SRX27536440         yes            yes
# 1089      sra   37124423   SRX27536446         yes            yes
#
#      is_paired_end      lib_prep     tech_10x    cell_prep  \
# 0              yes  10x_Genomics  3_prime_gex  single_cell
# 1              yes  10x_Genomics  3_prime_gex  single_cell
# 2              yes  10x_Genomics  3_prime_gex  single_cell
# 3              yes  10x_Genomics  3_prime_gex  single_cell
# 4              yes  10x_Genomics  3_prime_gex  single_cell
# ...            ...           ...          ...          ...
# 1085           yes  10x_Genomics  3_prime_gex  single_cell
# 1086           yes  10x_Genomics  3_prime_gex  single_cell
# 1087           yes  10x_Genomics  3_prime_gex  single_cell
# 1088           yes  10x_Genomics  3_prime_gex  single_cell
# 1089           yes  10x_Genomics  3_prime_gex  single_cell
#
#                      organism                                         tissue  \
# 0     Drosophila melanogaster                       ureter and lower tubules
# 1                 Danio rerio                                 whole organism
# 2                 Danio rerio                                 whole organism
# 3                 Danio rerio                                     caudal fin
# 4                    Zea mays  SAM (Shoot Apical Meristem), plastochrons 1-6
# ...                       ...                                            ...
# 1085            Gallus gallus                                         Somite
# 1086            Gallus gallus                                         somite
# 1087   Caenorhabditis elegans                         rab-3::tagRFP+ neurons
# 1088     Solanum lycopersicum                              Adventitious root
# 1089     Solanum lycopersicum                              Adventitious root
#
#                disease                                       purturbation  \
# 0        not specified                                      not specified
# 1        not specified                                      not specified
# 2        not specified  micro-injected with gRNA pool and Cas9 mRNA mi...
# 3     Strongyloidiasis  Ivermectin, Thiabendazole, Mebendazole, Albend...
# 4                 none                                               none
# ...                ...                                                ...
# 1085            unsure                                             unsure
# 1086     not specified                                      not specified
# 1087              none                                  young adult males
# 1088            unsure                                 Hydroponic culture
# 1089            unsure                                 Hydroponic culture
#
#                        cell_line czi_collection_id czi_collection_name  \
# 0                 not applicable              None                None
# 1                 not applicable              None                None
# 2                 not applicable              None                None
# 3                         unsure              None                None
# 4     single cells (protoplasts)              None                None
# ...                          ...               ...                 ...
# 1085                      unsure              None                None
# 1086               not specified              None                None
# 1087                      MOS264              None                None
# 1088                      unsure              None                None
# 1089              not applicable              None                None
#
#                              notes                 created_at  \
# 0     Metadata obtained by SRAgent 2025-02-10 13:20:27.590900
# 1     Metadata obtained by SRAgent 2025-02-10 14:05:29.747741
# 2     Metadata obtained by SRAgent 2025-02-08 05:25:29.492257
# 3     Metadata obtained by SRAgent 2025-02-09 18:20:32.244925
# 4     Metadata obtained by SRAgent 2025-02-10 18:25:31.352826
# ...                            ...                        ...
# 1085  Metadata obtained by SRAgent 2025-02-08 16:15:27.270171
# 1086  Metadata obtained by SRAgent 2025-02-10 04:45:31.519252
# 1087  Metadata obtained by SRAgent 2025-02-09 15:55:28.997356
# 1088  Metadata obtained by SRAgent 2025-02-16 10:30:26.807923
# 1089  Metadata obtained by SRAgent 2025-02-16 10:30:26.807923
#
#                      updated_at  \
# 0    2025-02-10 13:23:31.772165
# 1    2025-02-10 14:09:52.175351
# 2    2025-02-08 05:26:38.375022
# 3    2025-02-09 18:21:47.191491
# 4    2025-02-10 18:29:03.676546
# ...                         ...
# 1085 2025-02-08 16:18:16.793937
# 1086 2025-02-10 04:46:54.953339
# 1087 2025-02-09 15:57:05.945129
# 1088 2025-02-16 10:31:36.464400
# 1089 2025-02-16 10:31:38.107846
#
#                                                    path
# 0     /processed_datasets/scRecount/scRecounter/prod...
# 1     /processed_datasets/scRecount/scRecounter/prod...
# 2     /processed_datasets/scRecount/scRecounter/prod...
# 3     /processed_datasets/scRecount/scRecounter/prod...
# 4     /processed_datasets/scRecount/scRecounter/prod...
# ...                                                 ...
# 1085  /processed_datasets/scRecount/scRecounter/prod...
# 1086  /processed_datasets/scRecount/scRecounter/prod...
# 1087  /processed_datasets/scRecount/scRecounter/prod...
# 1088  /processed_datasets/scRecount/scRecounter/prod...
# 1089  /processed_datasets/scRecount/scRecounter/prod...
#
# [1090 rows x 20 columns]

# %%
srx_metadata["organism"].value_counts()
# Out:
# organism
# Mus musculus               100
# Macaca mulatta             100
# Sus scrofa                 100
# Homo sapiens               100
# Danio rerio                 98
# Arabidopsis thaliana        98
# Drosophila melanogaster     96
# Gallus gallus               72
# Heterocephalus glaber       68
# Bos taurus                  41
# Pan troglodytes             34
# Zea mays                    31
# Caenorhabditis elegans      30
# Oryctolagus cuniculus       29
# Oryza sativa                27
# Callithrix jacchus          21
# Ovis aries                  20
# Equus caballus              11
# Solanum lycopersicum         9
# Schistosoma mansoni          3
# Gorilla gorilla              2
# Name: count, dtype: int64

# %%
# write to csv
srx_metadata.sort_values(["organism"]).to_csv("species_umap.csv", index=False)
